# %% [markdown]
# # Web Scraping
#
# Lots of great data is available online, but available through inconveniently formatted web pages. When this is the case, sometimes you can simply copy and paste the data into a .csv file and go on with your life. But if there are many records to parse and combine into a dataset, that might be impossible. Can we automate the collection of data from online sources?
#
# This is called web scraping. Broadly speaking: Web scraping is legal, but what you plan to do with the results of your scraping might not be. In general, most sites do not want you to scrape them at this point, but there is not really a way to stop you if you are sufficiently motivated. Be careful to use server resources respectfully (not too many requests per unit time), think seriously about privacy concerns, and be careful who you share your work with and how it is used.
#
# We'll be scraping data about used cars in Charlottesville from Craigslist, particularly this page: https://charlottesville.craigslist.org/search/cta?purveyor=owner#search=1~gallery~0~0

# %% [markdown]
# We'll use the `requests` package to get web pages off the Internet and into Python. Again, we'll use a header with a user-agent that masks our true identity so that we're not rejected by the server. This particular url points to the car listings for Craigslist in Charlottesville. To use requests, you pass a `url` for the page you want and a `header` that controls how you appear to the server to `requests.get`:

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import requests # Page requests

header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:124.0) Gecko/20100101 Firefox/124.0'} # How we wish to appear to CL
url = 'https://charlottesville.craigslist.org/search/cta?purveyor=owner#search=1~gallery~0~0' # The page we want to scrape
raw = requests.get(url,headers=header) # Get page

# %% [markdown]
# Now that we have that particular page available locally, we want to **parse** it and get results from it. To do that, we can use a package called `beautifulSoup` or `bs4`.
#
# What does `beautifulSoup` do for us? Let's go to the web page of interest. You probably see something like this:
#
# ![Listings](./src/craigslist.png "Craigslist")
#
# But if you "view page source" -- which is CTRL+U -- in Chrome, you see what the computer sees:
#
# ![Listings](./src/craigslist_source.png "Craigslist")
#
# Since your web browser needs lots of instructions about how to render the text, pictures, and other content on your web page, there are a lot of clues about where the data live and how to extricate them from a page. These clues are called **tags**. If you wander the source for the search page on cars, you see a particular `class = "cl-static-search-result"` term appear attached to each listing:
#
# ![Listings](./src/listing.png "Craigslist")
#
# This structure can be exploited to search the page for information. This kind of detective work -- looking at the page source, finding the interesting tags, and then searching the page with `beautifulSoup` -- is the basic job of web scraping.
#
# What I do is look at the rendered page, find the text I want and copy it, then search for that text in the HTML code that the computer sees. When I find the text I want, I look for the tag nearby. Here, it's `cl-static-search-result`: That's what I'll want beautifulSoup to search for.

# %% [markdown]
# The following code chunk takes the raw content from `requests` and turns it into a beautifulSoup object, which can search the page and return results for us:

# %%
from bs4 import BeautifulSoup as soup # HTML parser
bsObj = soup(raw.content,'html.parser') # Parse the html
listings = bsObj.find_all(class_="cl-static-search-result") # Find all listings of the kind we want

# %% [markdown]
# Why is the argument `class_` and not just `class`? The word `class` is a reserved keyword for Python, and cannot be used by anyone else, similar to `True` and `False`. But since we want the `class = "cl-static-search-result"` terms, we need to use the `class_` argument to the `.find_all` method.
#
# The `.find_all` function dredges the entire page and finds all the instances of `class = "cl-static-search-result"`, resulting in a list of entries. We can then parse the entries.
#
# Parsing the entries can be a challenge! We have to go back to what a listing looks like, and look at the tags within the listing. They're typically `div` tags with a `class` like price or location. You then have to experiment a bit with `.find` and the HTML to make sure you're getting the information you want. For each listing, the `.find` method to search within the listing record for specific information, but it's typically still wrapped in the tag. To get the real information we want, we can then use `.get_text()`. I end up using a code chunk to experiment and play with a record to make sure I'm getting as close to what I want as possible.
#
# In the code below, two more things happen. You don't need to do them in your work, but they're helpful to know about.
#
# First, I would like to get the brand of the car from the post title, if possible. To do this, I split the title into words using `title.split()`, and then I use a list comprehension to look over every word in the title and check whether it appears in the `brands` list.
#
# Second, I would like to get the year the car was built, if possible, so I can determine the vehicle's age. To do this, I use a thing called **regular expressions** that provides a language for expressing patterns. Do I remember how to do this off the top of my head? No, I read a few pages in a book and looked on StackOverflow for answers. Roughly, in order to express the idea "any year starting with 20xx," you can write `20[0-9][0-9]`, and for "any year starting with 19xx," you can write `19[0-9][0-9]`. The `[0-9]`'s act as wildcards for any digit. This allows me to use the `re` package to find any instances of year-like numbers in the title text, using `re.search(r'20[0-9][0-9]|19[0-9][0-9]', title )`.
#
# This is all nested in a for-loop over the listings, and the data is appended to a list.

# %%
import re # Regular expressions

brands = ['honda', 'dodge','toyota','ford','tesla','gmc','jeep','bmw','mitsubishi','mazda',
          'volvo','audi','volkswagen','chevy','chevrolet','acura','kia','subaru','lexus',
          'cadillac','buick','porsche','infiniti']

data = [] # We'll save our listings in this object
for k in range( len(listings) ):
    title = listings[k].find('div',class_='title').get_text().lower()
    price = listings[k].find('div',class_='price').get_text()
    link = listings[k].find(href=True)['href']
    # Get brand from the title string:
    words = title.split()
    hits = [word for word in words if word in brands] # Find brands in the title
    if len(hits) == 0:
        brand = 'missing'
    else:
        brand = hits[0]
    # Get years from title string:
    regex_search = re.search(r'20[0-9][0-9]|19[0-9][0-9]', title ) # Find year references
    if regex_search is None: # If no hits, record year as missing value
        year = np.nan
    else: # If hits, record year as first match
        year = regex_search.group(0)
    #
    data.append({'title':title,'price':price,'year':year,'link':link,'brand':brand})

# %% [markdown]
# With the data scraped from Craigslist, we can put it in a dataframe and wrangle it. Of course, price and year come in as text, not numbers, and need to be typecast/coerced:

# %%
## Wrangle the data
df = pd.DataFrame.from_dict(data)
df['price'] = df['price'].str.replace('$','')
df['price'] = df['price'].str.replace(',','')
df['price'] = pd.to_numeric(df['price'],errors='coerce')
df['year'] = pd.to_numeric(df['year'],errors='coerce')
df['age'] = 2025-df['year']
print(df.shape)
df.to_csv('./src/craigslist_cville_cars.csv') # Save data in case of a disaster
df.head()
# Out:
# (46, 6)
#                                                title  price    year  \
# 0                      a sweet sedan avalon xle plus  24000     NaN
# 1  1998 gmc sierra 1500 sl truck auto rwd <103,00...   6950  1998.0
# 2        gmc sierra 3500hd 6.6 duramax diesel dually  26000     NaN
# 3                              2007 chrysler sebring   2900  2007.0
# 4                               2012 nissan versa sl   3500  2012.0
#
#                                                 link    brand   age
# 0  https://charlottesville.craigslist.org/cto/d/c...  missing   NaN
# 1  https://charlottesville.craigslist.org/cto/d/l...      gmc  27.0
# 2  https://charlottesville.craigslist.org/cto/d/c...      gmc   NaN
# 3  https://charlottesville.craigslist.org/cto/d/c...  missing  18.0
# 4  https://charlottesville.craigslist.org/cto/d/c...  missing  13.0

# %% [markdown]
# With the data in and wrangled, we can now do some analysis:

# %%
print(df['price'].describe())
df['price'].hist(grid=False)
plt.show()
print(df['age'].describe())
df['age'].hist(grid=False)
plt.show()
# Out:
# count       46.000000
# mean     11983.630435
# std      13656.112410
# min       2000.000000
# 25%       4037.500000
# 50%       6725.000000
# 75%      13350.000000
# max      62800.000000
# Name: price, dtype: float64
# count    41.000000
# mean     24.121951
# std      16.315936
# min       6.000000
# 25%      13.000000
# 50%      19.000000
# 75%      31.000000
# max      68.000000
# Name: age, dtype: float64

# %%
# Price by brand:
df.loc[:,['price','brand']].groupby('brand').describe()
# Out:
#            price                                                          \
#            count          mean           std      min       25%      50%
# brand
# audi         1.0  37000.000000           NaN  37000.0  37000.00  37000.0
# bmw          3.0  19966.666667  20813.537261   7900.0   7950.00   8000.0
# chevrolet    4.0  10875.000000   9393.038202   3000.0   3375.00   9000.0
# chevy        3.0  11616.666667  11515.677719   4450.0   4975.00   5500.0
# dodge        1.0  18900.000000           NaN  18900.0  18900.00  18900.0
# ford         3.0  21333.333333  29173.332572   3500.0   4500.00   5500.0
# gmc          2.0  16475.000000  13470.384182   6950.0  11712.50  16475.0
# honda        5.0   5629.800000   2372.328013   2300.0   4700.00   5900.0
# jeep         2.0   9500.000000      0.000000   9500.0   9500.00   9500.0
# lexus        2.0  11175.000000    318.198052  10950.0  11062.50  11175.0
# missing     14.0  10089.214286  16148.241324   2000.0   3312.50   4650.0
# mitsubishi   1.0   7300.000000           NaN   7300.0   7300.00   7300.0
# subaru       1.0   3900.000000           NaN   3900.0   3900.00   3900.0
# toyota       4.0   9549.750000   7072.121340   2199.0   4299.75   9500.0
#
#
#                  75%      max
# brand
# audi        37000.00  37000.0
# bmw         26000.00  44000.0
# chevrolet   16500.00  22500.0
# chevy       15200.00  24900.0
# dodge       18900.00  18900.0
# ford        30250.00  55000.0
# gmc         21237.50  26000.0
# honda        6500.00   8749.0
# jeep         9500.00   9500.0
# lexus       11287.50  11400.0
# missing      6749.75  62800.0
# mitsubishi   7300.00   7300.0
# subaru       3900.00   3900.0
# toyota      14750.00  17000.0

# %%
# Age by brand:
df.loc[:,['age','brand']].groupby('brand').describe()
# Out:
#              age
#            count       mean        std   min   25%   50%   75%   max
# brand
# audi         1.0   6.000000        NaN   6.0   6.0   6.0   6.0   6.0
# bmw          2.0  15.000000   1.414214  14.0  14.5  15.0  15.5  16.0
# chevrolet    4.0  44.000000  16.000000  36.0  36.0  36.0  44.0  68.0
# chevy        3.0  20.000000  12.124356   7.0  14.5  22.0  26.5  31.0
# dodge        1.0  27.000000        NaN  27.0  27.0  27.0  27.0  27.0
# ford         3.0  22.666667   1.154701  22.0  22.0  22.0  23.0  24.0
# gmc          1.0  27.000000        NaN  27.0  27.0  27.0  27.0  27.0
# honda        5.0  18.000000   9.000000  10.0  13.0  15.0  19.0  33.0
# jeep         2.0  22.000000  14.142136  12.0  17.0  22.0  27.0  32.0
# lexus        2.0  17.000000   5.656854  13.0  15.0  17.0  19.0  21.0
# missing     11.0  30.636364  23.585049   7.0  12.0  20.0  49.0  68.0
# mitsubishi   1.0  17.000000        NaN  17.0  17.0  17.0  17.0  17.0
# subaru       1.0  11.000000        NaN  11.0  11.0  11.0  11.0  11.0
# toyota       4.0  15.500000   3.109126  12.0  13.5  15.5  17.5  19.0

# %%
ax = sns.scatterplot(data=df, x='age', y='price',hue='brand')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

# %%
df['log_price'] = np.log(df['price'])
df['log_age'] = np.log(df['age'])

ax = sns.scatterplot(data=df, x='log_age', y='log_price',hue='brand')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

print(df.loc[:,['log_price','log_age']].cov())
print(df.loc[:,['log_price','log_age']].corr())
# Out:
#            log_price   log_age
# log_price   0.783367 -0.196806
# log_age    -0.196806  0.382606
#            log_price   log_age
# log_price   1.000000 -0.376511
# log_age    -0.376511  1.000000

# %% [markdown]
# ## The Lab:
#
#
# 1. Pick something else on Craigslist besides used cars: Musical instruments, roommates, antiques, etc. Look at the search page and its source code. Record which fields/data you would like to gather, and what kinds of basic EDA you'd do with it.
# 2. Get your search results of interest using `requests` and extract data from them using `beautifulSoup`, using code similar to what's above.
# 3. Wrangle your data into a dataframe and do some basic descriptions and plots. Try to find some interesting relationships or stories to tell about your data.

# %%
header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:124.0) Gecko/20100101 Firefox/124.0'} # How we wish to appear to CL
url = 'https://charlottesville.craigslist.org/search/fua?purveyor=owner#search=2~gallery~0' # The page we want to scrape
raw = requests.get(url,headers=header) # Get page

# %%
from bs4 import BeautifulSoup as soup # HTML parser
bsObj = soup(raw.content,'html.parser') # Parse the html
listings = bsObj.find_all(class_="cl-static-search-result") # Find all listings of the kind we want
listings
# Out:
# [<li class="cl-static-search-result" title="Bakhtiari Persian Oriental Rug">
#  <a href="https://charlottesville.craigslist.org/fuo/d/lexington-bakhtiari-persian-oriental-rug/7912906392.html">
#  <div class="title">Bakhtiari Persian Oriental Rug</div>
#  <div class="details">
#  <div class="price">$350</div>
#  <div class="location">
#                          Lexington
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Plant Stand or Table Base">
#  <a href="https://charlottesville.craigslist.org/fuo/d/lexington-plant-stand-or-table-base/7894557773.html">
#  <div class="title">Plant Stand or Table Base</div>
#  <div class="details">
#  <div class="price">$10</div>
#  <div class="location">
#                          Lexington, Virginia
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Sept 2025 Twin Mattress/Frame/Spring">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-sept-2025-twin-mattress/7912844628.html">
#  <div class="title">Sept 2025 Twin Mattress/Frame/Spring</div>
#  <div class="details">
#  <div class="price">$175</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="custom storage unit ~ custom built cabinets">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-custom-storage-unit/7896397168.html">
#  <div class="title">custom storage unit ~ custom built cabinets</div>
#  <div class="details">
#  <div class="price">$6,500</div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Ball pythons rehome">
#  <a href="https://charlottesville.craigslist.org/fuo/d/louisa-ball-pythons-rehome/7891903993.html">
#  <div class="title">Ball pythons rehome</div>
#  <div class="details">
#  <div class="price">$150</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Bunk bed">
#  <a href="https://charlottesville.craigslist.org/fuo/d/louisa-bunk-bed/7890994078.html">
#  <div class="title">Bunk bed</div>
#  <div class="details">
#  <div class="price">$90</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Rehoming ball pythons">
#  <a href="https://charlottesville.craigslist.org/fuo/d/louisa-rehoming-ball-pythons/7894941273.html">
#  <div class="title">Rehoming ball pythons</div>
#  <div class="details">
#  <div class="price">$123</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Sanus Lowboy Three-shelf Component cabinet for AV equipment: CFV69">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-sanus-lowboy-three/7912809526.html">
#  <div class="title">Sanus Lowboy Three-shelf Component cabinet for AV equipment: CFV69</div>
#  <div class="details">
#  <div class="price">$450</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2 Wrought Iron Glass Top Tables">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-wrought-iron-glass-top/7905558079.html">
#  <div class="title">2 Wrought Iron Glass Top Tables</div>
#  <div class="details">
#  <div class="price">$40</div>
#  <div class="location">
#                          Northern Albemarle
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="GRAPEVINE TABLE">
#  <a href="https://charlottesville.craigslist.org/fuo/d/somerset-grapevine-table/7882421991.html">
#  <div class="title">GRAPEVINE TABLE</div>
#  <div class="details">
#  <div class="price">$2,800</div>
#  <div class="location">
#                          Gordonsville, Va.
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="This ends up/ Dresser">
#  <a href="https://charlottesville.craigslist.org/fuo/d/raphine-this-ends-up-dresser/7888143547.html">
#  <div class="title">This ends up/ Dresser</div>
#  <div class="details">
#  <div class="price">$100</div>
#  <div class="location">
#                          Raphine
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="This ends up/ student desk">
#  <a href="https://charlottesville.craigslist.org/fuo/d/raphine-this-ends-up-student-desk/7888133311.html">
#  <div class="title">This ends up/ student desk</div>
#  <div class="details">
#  <div class="price">$175</div>
#  <div class="location">
#                          Raphine
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Rock and Roll Art Print">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-rock-and-roll-art-print/7911715594.html">
#  <div class="title">Rock and Roll Art Print</div>
#  <div class="details">
#  <div class="price">$150</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Flexible Gooseneck Desk Lamp">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-flexible-gooseneck-desk/7906204982.html">
#  <div class="title">Flexible Gooseneck Desk Lamp</div>
#  <div class="details">
#  <div class="price">$30</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Beautiful Oak End Tables">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-beautiful-oak-end-tables/7903377594.html">
#  <div class="title">Beautiful Oak End Tables</div>
#  <div class="details">
#  <div class="price">$225</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Laundry Hamper / Storage">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-laundry-hamper-storage/7903377646.html">
#  <div class="title">Laundry Hamper / Storage</div>
#  <div class="details">
#  <div class="price">$40</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Mahogany End Tables">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-mahogany-end-tables/7882857444.html">
#  <div class="title">Mahogany End Tables</div>
#  <div class="details">
#  <div class="price">$250</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Queen Anne Style Upholstered Chair">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-queen-anne-style/7887062392.html">
#  <div class="title">Queen Anne Style Upholstered Chair</div>
#  <div class="details">
#  <div class="price">$175</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Mahogany Display Table with Serving Tray">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-mahogany-display-table/7881158584.html">
#  <div class="title">Mahogany Display Table with Serving Tray</div>
#  <div class="details">
#  <div class="price">$150</div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Rock and Roll Art Print">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-rock-and-roll-art-print/7910497963.html">
#  <div class="title">Rock and Roll Art Print</div>
#  <div class="details">
#  <div class="price">$150</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Vintage Berman Bronze &amp; Art Glass Deco Style Table Lamps">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-vintage-berman-bronze/7912147487.html">
#  <div class="title">Vintage Berman Bronze &amp; Art Glass Deco Style Table Lamps</div>
#  <div class="details">
#  <div class="price">$125</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Sofa and chairs">
#  <a href="https://charlottesville.craigslist.org/fuo/d/woodberry-forest-sofa-and-chairs/7890098953.html">
#  <div class="title">Sofa and chairs</div>
#  <div class="details">
#  <div class="price">$75</div>
#  <div class="location">
#                          Orange
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="3 bar stools all 1 price">
#  <a href="https://charlottesville.craigslist.org/fuo/d/greenwood-bar-stools-all-price/7912736072.html">
#  <div class="title">3 bar stools all 1 price</div>
#  <div class="details">
#  <div class="price">$30</div>
#  <div class="location">
#                          Crozet
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Brand New TV Table with Wheels">
#  <a href="https://charlottesville.craigslist.org/fuo/d/white-hall-brand-new-tv-table-with/7885349879.html">
#  <div class="title">Brand New TV Table with Wheels</div>
#  <div class="details">
#  <div class="price">$45</div>
#  <div class="location">
#                          CROZET
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Vintage Handmade Wooden Table with Magazine/Newspaper Holder">
#  <a href="https://charlottesville.craigslist.org/fuo/d/white-hall-vintage-handmade-wooden/7904722873.html">
#  <div class="title">Vintage Handmade Wooden Table with Magazine/Newspaper Holder</div>
#  <div class="details">
#  <div class="price">$40</div>
#  <div class="location">
#                          Crozet
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Pair of midcentury modern vintage lamps with 3-way lighting">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-pair-of-midcentury/7896342353.html">
#  <div class="title">Pair of midcentury modern vintage lamps with 3-way lighting</div>
#  <div class="details">
#  <div class="price">$100</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Desk">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-desk/7912652122.html">
#  <div class="title">Desk</div>
#  <div class="details">
#  <div class="price">$35</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Pub Table Set!">
#  <a href="https://charlottesville.craigslist.org/fuo/d/bremo-bluff-pub-table-set/7886018951.html">
#  <div class="title">Pub Table Set!</div>
#  <div class="details">
#  <div class="price">$125</div>
#  <div class="location">
#                          Bremo Bluff
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Pair of Stools!">
#  <a href="https://charlottesville.craigslist.org/fuo/d/bremo-bluff-pair-of-stools/7886020309.html">
#  <div class="title">Pair of Stools!</div>
#  <div class="details">
#  <div class="price">$45</div>
#  <div class="location">
#                          Bremo Bluff
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Solid Oak Vintage Desk!">
#  <a href="https://charlottesville.craigslist.org/fuo/d/bremo-bluff-solid-oak-vintage-desk/7895717429.html">
#  <div class="title">Solid Oak Vintage Desk!</div>
#  <div class="details">
#  <div class="price">$295</div>
#  <div class="location">
#                          Bremo Bluff
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Small Table Set!">
#  <a href="https://charlottesville.craigslist.org/fuo/d/bremo-bluff-small-table-set/7902990395.html">
#  <div class="title">Small Table Set!</div>
#  <div class="details">
#  <div class="price">$125</div>
#  <div class="location">
#                          Bremo Bluff
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Highboy Chest, 2pc">
#  <a href="https://charlottesville.craigslist.org/fuo/d/bremo-bluff-highboy-chest-2pc/7908735642.html">
#  <div class="title">Highboy Chest, 2pc</div>
#  <div class="details">
#  <div class="price">$450</div>
#  <div class="location">
#                          Bremo Bluff
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Oak Chest Of Drawer!">
#  <a href="https://charlottesville.craigslist.org/fuo/d/bremo-bluff-oak-chest-of-drawer/7908736210.html">
#  <div class="title">Oak Chest Of Drawer!</div>
#  <div class="details">
#  <div class="price">$350</div>
#  <div class="location">
#                          Bremo Bluff
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Oak long dresser with mirror!">
#  <a href="https://charlottesville.craigslist.org/fuo/d/bremo-bluff-oak-long-dresser-with-mirror/7908739216.html">
#  <div class="title">Oak long dresser with mirror!</div>
#  <div class="details">
#  <div class="price">$395</div>
#  <div class="location">
#                          Bremo Bluff
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Oak Wardrobe Chest">
#  <a href="https://charlottesville.craigslist.org/fuo/d/bremo-bluff-oak-wardrobe-chest/7908737146.html">
#  <div class="title">Oak Wardrobe Chest</div>
#  <div class="details">
#  <div class="price">$350</div>
#  <div class="location">
#                          Bremo Bluff
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Solid Wood Chest of Drawer!">
#  <a href="https://charlottesville.craigslist.org/fuo/d/bremo-bluff-solid-wood-chest-of-drawer/7908741202.html">
#  <div class="title">Solid Wood Chest of Drawer!</div>
#  <div class="details">
#  <div class="price">$225</div>
#  <div class="location">
#                          Bremo Bluff
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Natuzzi Leather Sofa">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-natuzzi-leather-sofa/7909728367.html">
#  <div class="title">Natuzzi Leather Sofa</div>
#  <div class="details">
#  <div class="price">$900</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="METAL &amp; WOOD DINING TABLE WITH ATTACHED SWING CHAIRS">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-metal-wood-dining-table/7905446372.html">
#  <div class="title">METAL &amp; WOOD DINING TABLE WITH ATTACHED SWING CHAIRS</div>
#  <div class="details">
#  <div class="price">$700</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Desk /work table">
#  <a href="https://charlottesville.craigslist.org/fuo/d/louisa-desk-work-table/7909048415.html">
#  <div class="title">Desk /work table</div>
#  <div class="details">
#  <div class="price">$20</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Piecrust edge Chippendale tilt top occasional table">
#  <a href="https://charlottesville.craigslist.org/fuo/d/louisa-piecrust-edge-chippendale-tilt/7908840265.html">
#  <div class="title">Piecrust edge Chippendale tilt top occasional table</div>
#  <div class="details">
#  <div class="price">$200</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Unique Chairs">
#  <a href="https://charlottesville.craigslist.org/fuo/d/louisa-unique-chairs/7894370574.html">
#  <div class="title">Unique Chairs</div>
#  <div class="details">
#  <div class="price">$35</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Desk with drawer">
#  <a href="https://charlottesville.craigslist.org/fuo/d/louisa-desk-with-drawer/7894366069.html">
#  <div class="title">Desk with drawer</div>
#  <div class="details">
#  <div class="price">$20</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="TV stand / Entertainment center cabinet">
#  <a href="https://charlottesville.craigslist.org/fuo/d/montpelier-station-tv-stand/7904656437.html">
#  <div class="title">TV stand / Entertainment center cabinet</div>
#  <div class="details">
#  <div class="price">$25</div>
#  <div class="location">
#                          Gordonsville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Patio table">
#  <a href="https://charlottesville.craigslist.org/fuo/d/montpelier-station-patio-table/7896004689.html">
#  <div class="title">Patio table</div>
#  <div class="details">
#  <div class="price">$20</div>
#  <div class="location">
#                          Gordonsville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Arm chair">
#  <a href="https://charlottesville.craigslist.org/fuo/d/montpelier-station-arm-chair/7898392579.html">
#  <div class="title">Arm chair</div>
#  <div class="details">
#  <div class="price">$30</div>
#  <div class="location">
#                          Gordonsville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Vintage Table With Metal Base">
#  <a href="https://charlottesville.craigslist.org/fuo/d/louisa-vintage-table-with-metal-base/7882957135.html">
#  <div class="title">Vintage Table With Metal Base</div>
#  <div class="details">
#  <div class="price">$50</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Mirror">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-mirror/7882967708.html">
#  <div class="title">Mirror</div>
#  <div class="details">
#  <div class="price">$10</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="5'  4&quot; Beveled Door Mirror Only 3 Sides">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-4-beveled-door-mirror-only-sides/7910191127.html">
#  <div class="title">5'  4" Beveled Door Mirror Only 3 Sides</div>
#  <div class="details">
#  <div class="price">$30</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Framed 3 Piece Wall Pictures">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-framed-piece-wall-pictures/7897050811.html">
#  <div class="title">Framed 3 Piece Wall Pictures</div>
#  <div class="details">
#  <div class="price">$15</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Wall/Floor Small Bench Display Books/Doll etc">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-wall-floor-small-bench-display/7906037499.html">
#  <div class="title">Wall/Floor Small Bench Display Books/Doll etc</div>
#  <div class="details">
#  <div class="price">$10</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="White Pantry Cabinet/Jelly Storage Cabinet">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-white-pantry-cabinet-jelly-storage/7881504308.html">
#  <div class="title">White Pantry Cabinet/Jelly Storage Cabinet</div>
#  <div class="details">
#  <div class="price">$20</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Pair Wood White Green Seat Stools">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-pair-wood-white-green-seat-stools/7906657807.html">
#  <div class="title">Pair Wood White Green Seat Stools</div>
#  <div class="details">
#  <div class="price">$20</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="MCM inspired vintage Mobican chest of drawers and dresser with mirror">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-mcm-inspired-vintage/7909080652.html">
#  <div class="title">MCM inspired vintage Mobican chest of drawers and dresser with mirror</div>
#  <div class="details">
#  <div class="price">$800</div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Vintage Cedar Chest">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-vintage-cedar-chest/7897415090.html">
#  <div class="title">Vintage Cedar Chest</div>
#  <div class="details">
#  <div class="price">$90</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="3 Little Monkey Framed Picture">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-little-monkey-framed-picture/7907414933.html">
#  <div class="title">3 Little Monkey Framed Picture</div>
#  <div class="details">
#  <div class="price">$10</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Vintage Teak Plantation Chair with swing-out arms">
#  <a href="https://charlottesville.craigslist.org/fuo/d/scottsville-vintage-teak-plantation/7895752899.html">
#  <div class="title">Vintage Teak Plantation Chair with swing-out arms</div>
#  <div class="details">
#  <div class="price">$525</div>
#  <div class="location">
#                          Scottsville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Red upolstered chair">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-red-upolstered-chair/7886191473.html">
#  <div class="title">Red upolstered chair</div>
#  <div class="details">
#  <div class="price">$30</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Bundle: Tempur-Pedic Mattress, Coffee Table, Framed Pictures">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-bundle-tempur-pedic/7886190699.html">
#  <div class="title">Bundle: Tempur-Pedic Mattress, Coffee Table, Framed Pictures</div>
#  <div class="details">
#  <div class="price">$1,600</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title='Aubertin "Pit Stop" framed watercolor'>
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-aubertin-pit-stop/7886190947.html">
#  <div class="title">Aubertin "Pit Stop" framed watercolor</div>
#  <div class="details">
#  <div class="price">$375</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Rectangular Coffee Table with Leaded Glass">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-rectangular-coffee/7886191196.html">
#  <div class="title">Rectangular Coffee Table with Leaded Glass</div>
#  <div class="details">
#  <div class="price">$60</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title='"Home of the Desert Rat" by Maynard Dixon'>
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-home-of-the-desert-rat/7886192644.html">
#  <div class="title">"Home of the Desert Rat" by Maynard Dixon</div>
#  <div class="details">
#  <div class="price">$150</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Tempur-Pedic ProAdapt Mattress Full Size">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-tempur-pedic-proadapt/7886192932.html">
#  <div class="title">Tempur-Pedic ProAdapt Mattress Full Size</div>
#  <div class="details">
#  <div class="price">$1,300</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2 Kerosene Lamps">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-kerosene-lamps/7873833787.html">
#  <div class="title">2 Kerosene Lamps</div>
#  <div class="details">
#  <div class="price">$10</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="1 Old Kerosene Lamps No Chimney">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-old-kerosene-lamps-no-chimney/7873833827.html">
#  <div class="title">1 Old Kerosene Lamps No Chimney</div>
#  <div class="details">
#  <div class="price">$8</div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Football Lamp">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-football-lamp/7874712141.html">
#  <div class="title">Football Lamp</div>
#  <div class="details">
#  <div class="price">$10</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Lamp Ruffle Shade Glass">
#  <a href="https://charlottesville.craigslist.org/fuo/d/louisa-lamp-ruffle-shade-glass/7875716848.html">
#  <div class="title">Lamp Ruffle Shade Glass</div>
#  <div class="details">
#  <div class="price">$5</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Desk Lamp Goose Neck/Base Holder">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-desk-lamp-goose-neck-base-holder/7875720348.html">
#  <div class="title">Desk Lamp Goose Neck/Base Holder</div>
#  <div class="details">
#  <div class="price">$10</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Vintage Floor Glass Table Lamp">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-vintage-floor-glass-table-lamp/7877431604.html">
#  <div class="title">Vintage Floor Glass Table Lamp</div>
#  <div class="details">
#  <div class="price">$75</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2 Older Lamps">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-older-lamps/7881630220.html">
#  <div class="title">2 Older Lamps</div>
#  <div class="details">
#  <div class="price">$10</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Old Cape Cod Stoneware Lamp">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-old-cape-cod-stoneware-lamp/7881659154.html">
#  <div class="title">Old Cape Cod Stoneware Lamp</div>
#  <div class="details">
#  <div class="price">$20</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Lamps Working Condition">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-lamps-working-condition/7881660509.html">
#  <div class="title">Lamps Working Condition</div>
#  <div class="details">
#  <div class="price">$7</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Vintage Decorative Base Tall Table Lamp">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-vintage-decorative-base-tall-table/7890279277.html">
#  <div class="title">Vintage Decorative Base Tall Table Lamp</div>
#  <div class="details">
#  <div class="price">$40</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Metal Decorative Old Floor Lamp">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-metal-decorative-old-floor-lamp/7908903505.html">
#  <div class="title">Metal Decorative Old Floor Lamp</div>
#  <div class="details">
#  <div class="price">$10</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Microwave Cart">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-microwave-cart/7885919258.html">
#  <div class="title">Microwave Cart</div>
#  <div class="details">
#  <div class="price">$20</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="SPECIAL New Box TV Cart">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-special-new-box-tv-cart/7893304043.html">
#  <div class="title">SPECIAL New Box TV Cart</div>
#  <div class="details">
#  <div class="price">$20</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Microwave/TV Stand/ Dresser or Electronic Equipment">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-microwave-tv-stand-dresser-or/7912541294.html">
#  <div class="title">Microwave/TV Stand/ Dresser or Electronic Equipment</div>
#  <div class="details">
#  <div class="price">$50</div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Metal 6' Tower Stand 4 Glass Shelves">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-metal-tower-stand-glass-shelves/7874123033.html">
#  <div class="title">Metal 6' Tower Stand 4 Glass Shelves</div>
#  <div class="details">
#  <div class="price">$50</div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Microwave Stand">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-microwave-stand/7892463545.html">
#  <div class="title">Microwave Stand</div>
#  <div class="details">
#  <div class="price">$30</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Backers Rack Small Corner Black Metal">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-backers-rack-small-corner-black/7894166635.html">
#  <div class="title">Backers Rack Small Corner Black Metal</div>
#  <div class="details">
#  <div class="price">$30</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="4 Black Plastic Shelf Stand">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-black-plastic-shelf-stand/7896534555.html">
#  <div class="title">4 Black Plastic Shelf Stand</div>
#  <div class="details">
#  <div class="price">$20</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Bookcase/Display Shelves">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-bookcase-display-shelves/7872038267.html">
#  <div class="title">Bookcase/Display Shelves</div>
#  <div class="details">
#  <div class="price">$20</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Colorful Full Bookcase Style Headboard">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-colorful-full-bookcase-style/7874115397.html">
#  <div class="title">Colorful Full Bookcase Style Headboard</div>
#  <div class="details">
#  <div class="price">$20</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="SPECIAL Display/Bookcase Stand 3 Shelves">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-special-display-bookcase-stand/7880752281.html">
#  <div class="title">SPECIAL Display/Bookcase Stand 3 Shelves</div>
#  <div class="details">
#  <div class="price">$40</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Wood Woven Seat Small Rocking Chair">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-wood-woven-seat-small-rocking-chair/7876421200.html">
#  <div class="title">Wood Woven Seat Small Rocking Chair</div>
#  <div class="details">
#  <div class="price">$10</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Rattan Swivel, Gliding Rocker, Recline Chair">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-rattan-swivel-gliding-rocker/7906320708.html">
#  <div class="title">Rattan Swivel, Gliding Rocker, Recline Chair</div>
#  <div class="details">
#  <div class="price">$125</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Small Drop Leaf Table (2) Chairs">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-small-drop-leaf-table-chairs/7889737047.html">
#  <div class="title">Small Drop Leaf Table (2) Chairs</div>
#  <div class="details">
#  <div class="price">$50</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Ladder Back Chair">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-ladder-back-chair/7900361874.html">
#  <div class="title">Ladder Back Chair</div>
#  <div class="details">
#  <div class="price">$15</div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Small Heavy Straight Back School Type Chair/Land Nod Mfg">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-small-heavy-straight-back-school/7910595972.html">
#  <div class="title">Small Heavy Straight Back School Type Chair/Land Nod Mfg</div>
#  <div class="details">
#  <div class="price">$15</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2 Metal Frame Design Top/Fabric Seats Chairs">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-metal-frame-design-top-fabric/7886573861.html">
#  <div class="title">2 Metal Frame Design Top/Fabric Seats Chairs</div>
#  <div class="details">
#  <div class="price">$15</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2 Wood Dining Chairs">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-wood-dining-chairs/7910237983.html">
#  <div class="title">2 Wood Dining Chairs</div>
#  <div class="details">
#  <div class="price">$20</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="2 Black Decorative Leaf Design Back Bar Chairs">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-black-decorative-leaf-design-back/7911103073.html">
#  <div class="title">2 Black Decorative Leaf Design Back Bar Chairs</div>
#  <div class="details">
#  <div class="price">$20</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Ethan Allen Desk">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-ethan-allen-desk/7910630653.html">
#  <div class="title">Ethan Allen Desk</div>
#  <div class="details">
#  <div class="price">$150</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Drop Leaf Table">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-drop-leaf-table/7895917913.html">
#  <div class="title">Drop Leaf Table</div>
#  <div class="details">
#  <div class="price">$50</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Wood Server Drop Leaves">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-wood-server-drop-leaves/7900361774.html">
#  <div class="title">Wood Server Drop Leaves</div>
#  <div class="details">
#  <div class="price">$40</div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="End/Side/Coffee Table Drop Leaf">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-end-side-coffee-table-drop-leaf/7900988219.html">
#  <div class="title">End/Side/Coffee Table Drop Leaf</div>
#  <div class="details">
#  <div class="price">$20</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Arm Dining Chairs (11)">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-arm-dining-chairs-11/7881034616.html">
#  <div class="title">Arm Dining Chairs (11)</div>
#  <div class="details">
#  <div class="price">$5</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Vintage Wood Carving Settee">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-vintage-wood-carving-settee/7886393130.html">
#  <div class="title">Vintage Wood Carving Settee</div>
#  <div class="details">
#  <div class="price">$150</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Dresser (4) Drawers">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-dresser-drawers/7881355136.html">
#  <div class="title">Dresser (4) Drawers</div>
#  <div class="details">
#  <div class="price">$30</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title='Beautiful Design 42" Round Rug Backing'>
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-beautiful-design-42-round-rug/7875431742.html">
#  <div class="title">Beautiful Design 42" Round Rug Backing</div>
#  <div class="details">
#  <div class="price">$20</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Rug 13' 1/2&quot; x 9' 3&quot; Plus  Padding">
#  <a href="https://charlottesville.craigslist.org/fuo/d/troy-rug-9-plus-padding/7875763896.html">
#  <div class="title">Rug 13' 1/2" x 9' 3" Plus  Padding</div>
#  <div class="details">
#  <div class="price">$125</div>
#  <div class="location">
#                          Louisa
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Large wall sconce (BLACK)">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-large-wall-sconce-black/7903382148.html">
#  <div class="title">Large wall sconce (BLACK)</div>
#  <div class="details">
#  <div class="price">$250</div>
#  <div class="location">
#                          Near d'town C'ville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Wood Cabinet">
#  <a href="https://charlottesville.craigslist.org/fuo/d/earlysville-wood-cabinet/7912480094.html">
#  <div class="title">Wood Cabinet</div>
#  <div class="details">
#  <div class="price">$50</div>
#  <div class="location">
#                          Earlysville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Steelcase file cabinets">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-steelcase-file-cabinets/7912474967.html">
#  <div class="title">Steelcase file cabinets</div>
#  <div class="details">
#  <div class="price">$225</div>
#  <div class="location">
#                          Downtown Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Kurdish Persian Oriental Rug Runner">
#  <a href="https://charlottesville.craigslist.org/fuo/d/lexington-kurdish-persian-oriental-rug/7912468986.html">
#  <div class="title">Kurdish Persian Oriental Rug Runner</div>
#  <div class="details">
#  <div class="price">$400</div>
#  <div class="location">
#                          Lexington
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="MCM Rare Vintage Bamboo Folding Plant Ladder Stand, MCM Bookshelf">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-mcm-rare-vintage-bamboo/7872590674.html">
#  <div class="title">MCM Rare Vintage Bamboo Folding Plant Ladder Stand, MCM Bookshelf</div>
#  <div class="details">
#  <div class="price">$195</div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Super sac, foot stool, and blanket">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-super-sac-foot-stool/7906533358.html">
#  <div class="title">Super sac, foot stool, and blanket</div>
#  <div class="details">
#  <div class="price">$350</div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="SMALL WOOD TABLE WITH 2 CHAIRS">
#  <a href="https://charlottesville.craigslist.org/fuo/d/montpelier-station-small-wood-table/7905320982.html">
#  <div class="title">SMALL WOOD TABLE WITH 2 CHAIRS</div>
#  <div class="details">
#  <div class="price">$30</div>
#  <div class="location">
#                          GORDONSVILLE, VA.
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="LARGE OAK ROCKING CHAIR FOR SALE">
#  <a href="https://charlottesville.craigslist.org/fuo/d/montpelier-station-large-oak-rocking/7905114541.html">
#  <div class="title">LARGE OAK ROCKING CHAIR FOR SALE</div>
#  <div class="details">
#  <div class="price">$95</div>
#  <div class="location">
#                          GORDONSVILLE, VA.
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="RoveConcept Hugo Sectional, Black, Left-Hand-Facing, Chrome">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-roveconcept-hugo/7912447793.html">
#  <div class="title">RoveConcept Hugo Sectional, Black, Left-Hand-Facing, Chrome</div>
#  <div class="details">
#  <div class="price">$1,900</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Light Pink Vanity">
#  <a href="https://charlottesville.craigslist.org/fuo/d/montpelier-station-light-pink-vanity/7900254613.html">
#  <div class="title">Light Pink Vanity</div>
#  <div class="details">
#  <div class="price">$125</div>
#  <div class="location">
#                          Zion Crossroads
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Light Pink Vanity">
#  <a href="https://charlottesville.craigslist.org/fuo/d/montpelier-station-light-pink-vanity/7897804698.html">
#  <div class="title">Light Pink Vanity</div>
#  <div class="details">
#  <div class="price">$90</div>
#  <div class="location">
#                          Zion Crossroads
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Light Pink Vanity">
#  <a href="https://charlottesville.craigslist.org/fuo/d/montpelier-station-light-pink-vanity/7896333270.html">
#  <div class="title">Light Pink Vanity</div>
#  <div class="details">
#  <div class="price">$125</div>
#  <div class="location">
#                          Zion Crossroads
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="ZINGER! electric wheel chair">
#  <a href="https://charlottesville.craigslist.org/fuo/d/scottsville-zinger-electric-wheel-chair/7910952768.html">
#  <div class="title">ZINGER! electric wheel chair</div>
#  <div class="details">
#  <div class="price">$550</div>
#  <div class="location">
#                          Scottsville Virginia
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Kardiel Josef Kubus Style Mid-Century Modern Lounge Chair">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-kardiel-josef-kubus/7912398468.html">
#  <div class="title">Kardiel Josef Kubus Style Mid-Century Modern Lounge Chair</div>
#  <div class="details">
#  <div class="price">$400</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Kardiel Josef Kubus Style Mid-Century Modern Sofa 3 Seat">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-kardiel-josef-kubus/7912393652.html">
#  <div class="title">Kardiel Josef Kubus Style Mid-Century Modern Sofa 3 Seat</div>
#  <div class="details">
#  <div class="price">$1,000</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="VANITY AND NIGHT STAND">
#  <a href="https://charlottesville.craigslist.org/fuo/d/somerset-vanity-and-night-stand/7912370778.html">
#  <div class="title">VANITY AND NIGHT STAND</div>
#  <div class="details">
#  <div class="price">$120</div>
#  <div class="location">
#                          Gordonsville, Va.
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Pair of Lovely Upholstered Vintage Chairs">
#  <a href="https://charlottesville.craigslist.org/fuo/d/culpeper-pair-of-lovely-upholstered/7890928430.html">
#  <div class="title">Pair of Lovely Upholstered Vintage Chairs</div>
#  <div class="details">
#  <div class="price">$150</div>
#  <div class="location">
#                          Culpeper
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title='Samsung 42" TV with Stand'>
#  <a href="https://charlottesville.craigslist.org/fuo/d/ivy-samsung-42-tv-with-stand/7906385679.html">
#  <div class="title">Samsung 42" TV with Stand</div>
#  <div class="details">
#  <div class="price">$90</div>
#  <div class="location">
#                          Ivy
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Afghan Taimani Oriental Rug">
#  <a href="https://charlottesville.craigslist.org/fuo/d/lexington-afghan-taimani-oriental-rug/7912344533.html">
#  <div class="title">Afghan Taimani Oriental Rug</div>
#  <div class="details">
#  <div class="price">$100</div>
#  <div class="location">
#                          Lexington
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Kid's Rocking Chair">
#  <a href="https://charlottesville.craigslist.org/fuo/d/montpelier-station-kids-rocking-chair/7902072311.html">
#  <div class="title">Kid's Rocking Chair</div>
#  <div class="details">
#  <div class="price">$50</div>
#  <div class="location">
#                          Orange
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Kids Bed, Headboard Only">
#  <a href="https://charlottesville.craigslist.org/fuo/d/montpelier-station-kids-bed-headboard/7902072427.html">
#  <div class="title">Kids Bed, Headboard Only</div>
#  <div class="details">
#  <div class="price">$200</div>
#  <div class="location">
#                          Orange
#                      </div>
#  </div>
#  </a>
#  </li>,
# ...
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="SOLIAN WARE BY SOHO POTTERY LTD.">
#  <a href="https://charlottesville.craigslist.org/fuo/d/palmyra-solian-ware-by-soho-pottery-ltd/7901115915.html">
#  <div class="title">SOLIAN WARE BY SOHO POTTERY LTD.</div>
#  <div class="details">
#  <div class="price">$44</div>
#  <div class="location">
#                          PALMYRA, VA
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="PITCHER AND BOWL SETS BY IRONSTONE U.S.A FROM">
#  <a href="https://charlottesville.craigslist.org/fuo/d/palmyra-pitcher-and-bowl-sets-by/7901116065.html">
#  <div class="title">PITCHER AND BOWL SETS BY IRONSTONE U.S.A FROM</div>
#  <div class="details">
#  <div class="price">$25</div>
#  <div class="location">
#                          PALMYRA, VA
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="AUTHENTIC BARBARA MOCK NUMBERED (#1493)  FRAMED PRINT">
#  <a href="https://charlottesville.craigslist.org/fuo/d/palmyra-authentic-barbara-mock-numbered/7901116432.html">
#  <div class="title">AUTHENTIC BARBARA MOCK NUMBERED (#1493)  FRAMED PRINT</div>
#  <div class="details">
#  <div class="price">$20</div>
#  <div class="location">
#                          PALMYRA, VA
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="MIRRORS MIRRORS MIRRORS                                   FROM">
#  <a href="https://charlottesville.craigslist.org/fuo/d/palmyra-mirrors-mirrors-mirrors-from/7901116559.html">
#  <div class="title">MIRRORS MIRRORS MIRRORS                                   FROM</div>
#  <div class="details">
#  <div class="price">$25</div>
#  <div class="location">
#                          PALMYRA, VA
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="INDOOR/OUTDOOR METAL END TABLES EACH">
#  <a href="https://charlottesville.craigslist.org/fuo/d/keene-indoor-outdoor-metal-end-tables/7901116802.html">
#  <div class="title">INDOOR/OUTDOOR METAL END TABLES EACH</div>
#  <div class="details">
#  <div class="price">$30</div>
#  <div class="location">
#                          SCOTTSVILLE, VA
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="VINTAGE WICKER STROLLER">
#  <a href="https://charlottesville.craigslist.org/fuo/d/palmyra-vintage-wicker-stroller/7901117218.html">
#  <div class="title">VINTAGE WICKER STROLLER</div>
#  <div class="details">
#  <div class="price">$99</div>
#  <div class="location">
#                          PALMYRA,  VA 22963
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="BLACK LAQUERED BENCH">
#  <a href="https://charlottesville.craigslist.org/fuo/d/palmyra-black-laquered-bench/7901116861.html">
#  <div class="title">BLACK LAQUERED BENCH</div>
#  <div class="details">
#  <div class="price">$25</div>
#  <div class="location">
#                          PALMYRA, VA
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="EARLY AMERICAN STYLE ROCKING CHAIR">
#  <a href="https://charlottesville.craigslist.org/fuo/d/palmyra-early-american-style-rocking/7901116946.html">
#  <div class="title">EARLY AMERICAN STYLE ROCKING CHAIR</div>
#  <div class="details">
#  <div class="price">$50</div>
#  <div class="location">
#                          PALMYRA, VA
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Oushak Turkish Oriental Rug">
#  <a href="https://charlottesville.craigslist.org/fuo/d/lexington-oushak-turkish-oriental-rug/7910154300.html">
#  <div class="title">Oushak Turkish Oriental Rug</div>
#  <div class="details">
#  <div class="price">$800</div>
#  <div class="location">
#                          Lexington
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Chenar Persian Oriental Rug Runner">
#  <a href="https://charlottesville.craigslist.org/fuo/d/lexington-chenar-persian-oriental-rug/7910152344.html">
#  <div class="title">Chenar Persian Oriental Rug Runner</div>
#  <div class="details">
#  <div class="price">$350</div>
#  <div class="location">
#                          Lexington
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Make this Brown Overstuffed Leather Sofa yours today!">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-make-this-brown/7910064934.html">
#  <div class="title">Make this Brown Overstuffed Leather Sofa yours today!</div>
#  <div class="details">
#  <div class="price">$50</div>
#  <div class="location">
#                          Pritchett Ln near Forest Lakes
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Pair of Shaker Style or Danish Modern Stickley Chairs">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-pair-of-shaker-style-or/7908481655.html">
#  <div class="title">Pair of Shaker Style or Danish Modern Stickley Chairs</div>
#  <div class="details">
#  <div class="price">$400</div>
#  <div class="location">
#                          Shadwell
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Solid Cherry Bookshelf Contemporary">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-solid-cherry-bookshelf/7908482546.html">
#  <div class="title">Solid Cherry Bookshelf Contemporary</div>
#  <div class="details">
#  <div class="price">$400</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Pair of Shaker Style or Danish Modern Stickley Chairs">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-pair-of-shaker-style-or/7908462463.html">
#  <div class="title">Pair of Shaker Style or Danish Modern Stickley Chairs</div>
#  <div class="details">
#  <div class="price">$400</div>
#  <div class="location">
#                          Shadwell
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Sarouk Persian Oriental Rug">
#  <a href="https://charlottesville.craigslist.org/fuo/d/lexington-sarouk-persian-oriental-rug/7910020865.html">
#  <div class="title">Sarouk Persian Oriental Rug</div>
#  <div class="details">
#  <div class="price">$1,200</div>
#  <div class="location">
#                          Lexington
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Cute side/ coffee table">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-cute-side-coffee-table/7909991444.html">
#  <div class="title">Cute side/ coffee table</div>
#  <div class="details">
#  <div class="price">$40</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Pier 1 wicker chairs.">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-pier-wicker-chairs/7909990242.html">
#  <div class="title">Pier 1 wicker chairs.</div>
#  <div class="details">
#  <div class="price">$100</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Full size white canopy bed">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-full-size-white-canopy/7907624059.html">
#  <div class="title">Full size white canopy bed</div>
#  <div class="details">
#  <div class="price">$35</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Zabol Persian Oriental Rug">
#  <a href="https://charlottesville.craigslist.org/fuo/d/lexington-zabol-persian-oriental-rug/7909928974.html">
#  <div class="title">Zabol Persian Oriental Rug</div>
#  <div class="details">
#  <div class="price">$350</div>
#  <div class="location">
#                          Lexington
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Reclaimed Solid Wood Dresser">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-reclaimed-solid-wood/7909888263.html">
#  <div class="title">Reclaimed Solid Wood Dresser</div>
#  <div class="details">
#  <div class="price">$300</div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Two twin bed frames headboards and footboards (must take both)">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-two-twin-bed-frames/7897503139.html">
#  <div class="title">Two twin bed frames headboards and footboards (must take both)</div>
#  <div class="details">
#  <div class="price">$80</div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Yalameh Persian Oriental Rug">
#  <a href="https://charlottesville.craigslist.org/fuo/d/lexington-yalameh-persian-oriental-rug/7909633600.html">
#  <div class="title">Yalameh Persian Oriental Rug</div>
#  <div class="details">
#  <div class="price">$500</div>
#  <div class="location">
#                          Lexington
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Antique Enjilas Persian Oriental Rug">
#  <a href="https://charlottesville.craigslist.org/fuo/d/lexington-antique-enjilas-persian/7909627648.html">
#  <div class="title">Antique Enjilas Persian Oriental Rug</div>
#  <div class="details">
#  <div class="price">$350</div>
#  <div class="location">
#                          Lexington
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Twin Bed Headboards- 25 each/45 pair">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-twin-bed-headboards-25/7890352713.html">
#  <div class="title">Twin Bed Headboards- 25 each/45 pair</div>
#  <div class="details">
#  <div class="price">$25</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Modern Dog Crate">
#  <a href="https://charlottesville.craigslist.org/fuo/d/waynesboro-modern-dog-crate/7909551474.html">
#  <div class="title">Modern Dog Crate</div>
#  <div class="details">
#  <div class="price">$80</div>
#  <div class="location">
#                          Waynesboro
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Malayer Persian Oriental Rug Runner">
#  <a href="https://charlottesville.craigslist.org/fuo/d/lexington-malayer-persian-oriental-rug/7909511042.html">
#  <div class="title">Malayer Persian Oriental Rug Runner</div>
#  <div class="details">
#  <div class="price">$450</div>
#  <div class="location">
#                          Lexington
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Bassett Rolled Arm Sofa">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-bassett-rolled-arm-sofa/7909506639.html">
#  <div class="title">Bassett Rolled Arm Sofa</div>
#  <div class="details">
#  <div class="price">$150</div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Four Antique Rugs">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-four-antique-rugs/7909492335.html">
#  <div class="title">Four Antique Rugs</div>
#  <div class="details">
#  <div class="price">$750</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Mashad Persian Oriental Rug">
#  <a href="https://charlottesville.craigslist.org/fuo/d/lexington-mashad-persian-oriental-rug/7909446254.html">
#  <div class="title">Mashad Persian Oriental Rug</div>
#  <div class="details">
#  <div class="price">$850</div>
#  <div class="location">
#                          Lexington
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Overstuffed Plush Recliner">
#  <a href="https://charlottesville.craigslist.org/fuo/d/esmont-overstuffed-plush-recliner/7883085474.html">
#  <div class="title">Overstuffed Plush Recliner</div>
#  <div class="details">
#  <div class="price">$65</div>
#  <div class="location">
#                          Esmont
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Wooden coffee table">
#  <a href="https://charlottesville.craigslist.org/fuo/d/esmont-wooden-coffee-table/7883084713.html">
#  <div class="title">Wooden coffee table</div>
#  <div class="details">
#  <div class="price">$50</div>
#  <div class="location">
#                          Esmont
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Stools">
#  <a href="https://charlottesville.craigslist.org/fuo/d/esmont-stools/7883084989.html">
#  <div class="title">Stools</div>
#  <div class="details">
#  <div class="price">$5</div>
#  <div class="location">
#                          Esmont
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Solid Wood Folding Trestle Table">
#  <a href="https://charlottesville.craigslist.org/fuo/d/esmont-solid-wood-folding-trestle-table/7883084543.html">
#  <div class="title">Solid Wood Folding Trestle Table</div>
#  <div class="details">
#  <div class="price">$100</div>
#  <div class="location">
#                          Esmont
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="1960 Desota">
#  <a href="https://charlottesville.craigslist.org/fuo/d/waynesboro-1960-desota/7909394045.html">
#  <div class="title">1960 Desota</div>
#  <div class="details">
#  <div class="price">$4,000</div>
#  <div class="location">
#                          Waynesboro
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Nice Grayish Couch">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-nice-grayish-couch/7909387517.html">
#  <div class="title">Nice Grayish Couch</div>
#  <div class="details">
#  <div class="price">$100</div>
#  <div class="location">
#                          Charlottesville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Bar Wine Cart on Wheels">
#  <a href="https://charlottesville.craigslist.org/fuo/d/nellysford-bar-wine-cart-on-wheels/7909246888.html">
#  <div class="title">Bar Wine Cart on Wheels</div>
#  <div class="details">
#  <div class="price">$25</div>
#  <div class="location">
#                          Nellysford
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Comfy Red Chair">
#  <a href="https://charlottesville.craigslist.org/fuo/d/charlottesville-comfy-red-chair/7909245254.html">
#  <div class="title">Comfy Red Chair</div>
#  <div class="details">
#  <div class="price">$40</div>
#  <div class="location">
#                          Canterbury Hills
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Futon bed">
#  <a href="https://charlottesville.craigslist.org/fuo/d/barboursville-futon-bed/7898884618.html">
#  <div class="title">Futon bed</div>
#  <div class="details">
#  <div class="price">$200</div>
#  <div class="location">
#                          Barboursville
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Chairs. Solid oak">
#  <a href="https://charlottesville.craigslist.org/fuo/d/waynesboro-chairs-solid-oak/7909182803.html">
#  <div class="title">Chairs. Solid oak</div>
#  <div class="details">
#  <div class="price">$60</div>
#  <div class="location">
#                          Waynesboro
#                      </div>
#  </div>
#  </a>
#  </li>,
#  <li class="cl-static-search-result" title="Sold oak chairs">
#  <a href="https://charlottesville.craigslist.org/fuo/d/waynesboro-sold-oak-chairs/7909182639.html">
#  <div class="title">Sold oak chairs</div>
#  <div class="details">
#  <div class="price">$60</div>
#  <div class="location">
#                          Waynesboro
#                      </div>
#  </div>
#  </a>
#  </li>]

# %%
import re # Regular expressions

furniture_types = ["table", "chair", "bed", "sofa", "couch", "bench",
    "stool", "ottoman", "recliner", "futon", "loveseat",
    "settee", "desk", "vanity", "bar", "cart", "island",
    "cabinet", "shelf", "dresser", "wardrobe", "chest",
    "cupboard", "bookcase", "sideboard", "buffet", "credenza",
    "hutch", "armoire", "rack", "stand", "locker", "trunk",
    "crib", "cradle", "hammock", "cot", "headboard","rug","lamp"]

data = [] # We'll save our listings in this object
for k in range( len(listings) ):
    title = listings[k].find('div',class_='title').get_text().lower()
    price = listings[k].find('div',class_='price').get_text()
    link = listings[k].find(href=True)['href']
    # Get brand from the title string:
    words = title.split()
    hits = [word for word in words if word in furniture_types]

    if len(hits) == 0:
        furniture_type = 'missing'
    else:
        furniture_type = hits[0]
    # Get years from title string:
    regex_search = re.search(r'20[0-9][0-9]|19[0-9][0-9]', title ) # Find year references
    if regex_search is None: # If no hits, record year as missing value
        year = np.nan
    else: # If hits, record year as first match
        year = regex_search.group(0)
    #
    data.append({'title':title,'price':price,'year':year,'link':link,'furniture_type':furniture_type})

# %%
data
# Out:
# [{'title': 'bakhtiari persian oriental rug',
#   'price': '$350',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/lexington-bakhtiari-persian-oriental-rug/7912906392.html',
#   'furniture_type': 'rug'},
#  {'title': 'plant stand or table base',
#   'price': '$10',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/lexington-plant-stand-or-table-base/7894557773.html',
#   'furniture_type': 'stand'},
#  {'title': 'sept 2025 twin mattress/frame/spring',
#   'price': '$175',
#   'year': '2025',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-sept-2025-twin-mattress/7912844628.html',
#   'furniture_type': 'missing'},
#  {'title': 'custom storage unit ~ custom built cabinets',
#   'price': '$6,500',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-custom-storage-unit/7896397168.html',
#   'furniture_type': 'missing'},
#  {'title': 'ball pythons rehome',
#   'price': '$150',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/louisa-ball-pythons-rehome/7891903993.html',
#   'furniture_type': 'missing'},
#  {'title': 'bunk bed',
#   'price': '$90',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/louisa-bunk-bed/7890994078.html',
#   'furniture_type': 'bed'},
#  {'title': 'rehoming ball pythons',
#   'price': '$123',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/louisa-rehoming-ball-pythons/7894941273.html',
#   'furniture_type': 'missing'},
#  {'title': 'sanus lowboy three-shelf component cabinet for av equipment: cfv69',
#   'price': '$450',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-sanus-lowboy-three/7912809526.html',
#   'furniture_type': 'cabinet'},
#  {'title': '2 wrought iron glass top tables',
#   'price': '$40',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-wrought-iron-glass-top/7905558079.html',
#   'furniture_type': 'missing'},
#  {'title': 'grapevine table',
#   'price': '$2,800',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/somerset-grapevine-table/7882421991.html',
#   'furniture_type': 'table'},
#  {'title': 'this ends up/ dresser',
#   'price': '$100',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/raphine-this-ends-up-dresser/7888143547.html',
#   'furniture_type': 'dresser'},
#  {'title': 'this ends up/ student desk',
#   'price': '$175',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/raphine-this-ends-up-student-desk/7888133311.html',
#   'furniture_type': 'desk'},
#  {'title': 'rock and roll art print',
#   'price': '$150',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-rock-and-roll-art-print/7911715594.html',
#   'furniture_type': 'missing'},
#  {'title': 'flexible gooseneck desk lamp',
#   'price': '$30',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-flexible-gooseneck-desk/7906204982.html',
#   'furniture_type': 'desk'},
#  {'title': 'beautiful oak end tables',
#   'price': '$225',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-beautiful-oak-end-tables/7903377594.html',
#   'furniture_type': 'missing'},
#  {'title': 'laundry hamper / storage',
#   'price': '$40',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-laundry-hamper-storage/7903377646.html',
#   'furniture_type': 'missing'},
#  {'title': 'mahogany end tables',
#   'price': '$250',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-mahogany-end-tables/7882857444.html',
#   'furniture_type': 'missing'},
#  {'title': 'queen anne style upholstered chair',
#   'price': '$175',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-queen-anne-style/7887062392.html',
#   'furniture_type': 'chair'},
#  {'title': 'mahogany display table with serving tray',
#   'price': '$150',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-mahogany-display-table/7881158584.html',
#   'furniture_type': 'table'},
#  {'title': 'rock and roll art print',
#   'price': '$150',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-rock-and-roll-art-print/7910497963.html',
#   'furniture_type': 'missing'},
#  {'title': 'vintage berman bronze & art glass deco style table lamps',
#   'price': '$125',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-vintage-berman-bronze/7912147487.html',
#   'furniture_type': 'table'},
#  {'title': 'sofa and chairs',
#   'price': '$75',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/woodberry-forest-sofa-and-chairs/7890098953.html',
#   'furniture_type': 'sofa'},
#  {'title': '3 bar stools all 1 price',
#   'price': '$30',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/greenwood-bar-stools-all-price/7912736072.html',
#   'furniture_type': 'bar'},
#  {'title': 'brand new tv table with wheels',
#   'price': '$45',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/white-hall-brand-new-tv-table-with/7885349879.html',
#   'furniture_type': 'table'},
#  {'title': 'vintage handmade wooden table with magazine/newspaper holder',
#   'price': '$40',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/white-hall-vintage-handmade-wooden/7904722873.html',
#   'furniture_type': 'table'},
#  {'title': 'pair of midcentury modern vintage lamps with 3-way lighting',
#   'price': '$100',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-pair-of-midcentury/7896342353.html',
#   'furniture_type': 'missing'},
#  {'title': 'desk',
#   'price': '$35',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-desk/7912652122.html',
#   'furniture_type': 'desk'},
#  {'title': 'pub table set!',
#   'price': '$125',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/bremo-bluff-pub-table-set/7886018951.html',
#   'furniture_type': 'table'},
#  {'title': 'pair of stools!',
#   'price': '$45',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/bremo-bluff-pair-of-stools/7886020309.html',
#   'furniture_type': 'missing'},
#  {'title': 'solid oak vintage desk!',
#   'price': '$295',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/bremo-bluff-solid-oak-vintage-desk/7895717429.html',
#   'furniture_type': 'missing'},
#  {'title': 'small table set!',
#   'price': '$125',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/bremo-bluff-small-table-set/7902990395.html',
#   'furniture_type': 'table'},
#  {'title': 'highboy chest, 2pc',
#   'price': '$450',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/bremo-bluff-highboy-chest-2pc/7908735642.html',
#   'furniture_type': 'missing'},
#  {'title': 'oak chest of drawer!',
#   'price': '$350',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/bremo-bluff-oak-chest-of-drawer/7908736210.html',
#   'furniture_type': 'chest'},
#  {'title': 'oak long dresser with mirror!',
#   'price': '$395',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/bremo-bluff-oak-long-dresser-with-mirror/7908739216.html',
#   'furniture_type': 'dresser'},
#  {'title': 'oak wardrobe chest',
#   'price': '$350',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/bremo-bluff-oak-wardrobe-chest/7908737146.html',
#   'furniture_type': 'wardrobe'},
#  {'title': 'solid wood chest of drawer!',
#   'price': '$225',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/bremo-bluff-solid-wood-chest-of-drawer/7908741202.html',
#   'furniture_type': 'chest'},
#  {'title': 'natuzzi leather sofa',
#   'price': '$900',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-natuzzi-leather-sofa/7909728367.html',
#   'furniture_type': 'sofa'},
#  {'title': 'metal & wood dining table with attached swing chairs',
#   'price': '$700',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-metal-wood-dining-table/7905446372.html',
#   'furniture_type': 'table'},
#  {'title': 'desk /work table',
#   'price': '$20',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/louisa-desk-work-table/7909048415.html',
#   'furniture_type': 'desk'},
#  {'title': 'piecrust edge chippendale tilt top occasional table',
#   'price': '$200',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/louisa-piecrust-edge-chippendale-tilt/7908840265.html',
#   'furniture_type': 'table'},
#  {'title': 'unique chairs',
#   'price': '$35',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/louisa-unique-chairs/7894370574.html',
#   'furniture_type': 'missing'},
#  {'title': 'desk with drawer',
#   'price': '$20',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/louisa-desk-with-drawer/7894366069.html',
#   'furniture_type': 'desk'},
#  {'title': 'tv stand / entertainment center cabinet',
#   'price': '$25',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/montpelier-station-tv-stand/7904656437.html',
#   'furniture_type': 'stand'},
#  {'title': 'patio table',
#   'price': '$20',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/montpelier-station-patio-table/7896004689.html',
#   'furniture_type': 'table'},
#  {'title': 'arm chair',
#   'price': '$30',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/montpelier-station-arm-chair/7898392579.html',
#   'furniture_type': 'chair'},
#  {'title': 'vintage table with metal base',
#   'price': '$50',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/louisa-vintage-table-with-metal-base/7882957135.html',
#   'furniture_type': 'table'},
#  {'title': 'mirror',
#   'price': '$10',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-mirror/7882967708.html',
#   'furniture_type': 'missing'},
#  {'title': '5\'  4" beveled door mirror only 3 sides',
#   'price': '$30',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-4-beveled-door-mirror-only-sides/7910191127.html',
#   'furniture_type': 'missing'},
#  {'title': 'framed 3 piece wall pictures',
#   'price': '$15',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-framed-piece-wall-pictures/7897050811.html',
#   'furniture_type': 'missing'},
#  {'title': 'wall/floor small bench display books/doll etc',
#   'price': '$10',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-wall-floor-small-bench-display/7906037499.html',
#   'furniture_type': 'bench'},
#  {'title': 'white pantry cabinet/jelly storage cabinet',
#   'price': '$20',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-white-pantry-cabinet-jelly-storage/7881504308.html',
#   'furniture_type': 'cabinet'},
#  {'title': 'pair wood white green seat stools',
#   'price': '$20',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-pair-wood-white-green-seat-stools/7906657807.html',
#   'furniture_type': 'missing'},
#  {'title': 'mcm inspired vintage mobican chest of drawers and dresser with mirror',
#   'price': '$800',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-mcm-inspired-vintage/7909080652.html',
#   'furniture_type': 'chest'},
#  {'title': 'vintage cedar chest',
#   'price': '$90',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-vintage-cedar-chest/7897415090.html',
#   'furniture_type': 'chest'},
#  {'title': '3 little monkey framed picture',
#   'price': '$10',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-little-monkey-framed-picture/7907414933.html',
#   'furniture_type': 'missing'},
#  {'title': 'vintage teak plantation chair with swing-out arms',
#   'price': '$525',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/scottsville-vintage-teak-plantation/7895752899.html',
#   'furniture_type': 'chair'},
#  {'title': 'red upolstered chair',
#   'price': '$30',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-red-upolstered-chair/7886191473.html',
#   'furniture_type': 'chair'},
#  {'title': 'bundle: tempur-pedic mattress, coffee table, framed pictures',
#   'price': '$1,600',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-bundle-tempur-pedic/7886190699.html',
#   'furniture_type': 'missing'},
#  {'title': 'aubertin "pit stop" framed watercolor',
#   'price': '$375',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-aubertin-pit-stop/7886190947.html',
#   'furniture_type': 'missing'},
#  {'title': 'rectangular coffee table with leaded glass',
#   'price': '$60',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-rectangular-coffee/7886191196.html',
#   'furniture_type': 'table'},
#  {'title': '"home of the desert rat" by maynard dixon',
#   'price': '$150',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-home-of-the-desert-rat/7886192644.html',
#   'furniture_type': 'missing'},
#  {'title': 'tempur-pedic proadapt mattress full size',
#   'price': '$1,300',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-tempur-pedic-proadapt/7886192932.html',
#   'furniture_type': 'missing'},
#  {'title': '2 kerosene lamps',
#   'price': '$10',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-kerosene-lamps/7873833787.html',
#   'furniture_type': 'missing'},
#  {'title': '1 old kerosene lamps no chimney',
#   'price': '$8',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-old-kerosene-lamps-no-chimney/7873833827.html',
#   'furniture_type': 'missing'},
#  {'title': 'football lamp',
#   'price': '$10',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-football-lamp/7874712141.html',
#   'furniture_type': 'lamp'},
#  {'title': 'lamp ruffle shade glass',
#   'price': '$5',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/louisa-lamp-ruffle-shade-glass/7875716848.html',
#   'furniture_type': 'lamp'},
#  {'title': 'desk lamp goose neck/base holder',
#   'price': '$10',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-desk-lamp-goose-neck-base-holder/7875720348.html',
#   'furniture_type': 'desk'},
#  {'title': 'vintage floor glass table lamp',
#   'price': '$75',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-vintage-floor-glass-table-lamp/7877431604.html',
#   'furniture_type': 'table'},
#  {'title': '2 older lamps',
#   'price': '$10',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-older-lamps/7881630220.html',
#   'furniture_type': 'missing'},
#  {'title': 'old cape cod stoneware lamp',
#   'price': '$20',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-old-cape-cod-stoneware-lamp/7881659154.html',
#   'furniture_type': 'lamp'},
#  {'title': 'lamps working condition',
#   'price': '$7',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-lamps-working-condition/7881660509.html',
#   'furniture_type': 'missing'},
#  {'title': 'vintage decorative base tall table lamp',
#   'price': '$40',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-vintage-decorative-base-tall-table/7890279277.html',
#   'furniture_type': 'table'},
#  {'title': 'metal decorative old floor lamp',
#   'price': '$10',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-metal-decorative-old-floor-lamp/7908903505.html',
#   'furniture_type': 'lamp'},
#  {'title': 'microwave cart',
#   'price': '$20',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-microwave-cart/7885919258.html',
#   'furniture_type': 'cart'},
#  {'title': 'special new box tv cart',
#   'price': '$20',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-special-new-box-tv-cart/7893304043.html',
#   'furniture_type': 'cart'},
#  {'title': 'microwave/tv stand/ dresser or electronic equipment',
#   'price': '$50',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-microwave-tv-stand-dresser-or/7912541294.html',
#   'furniture_type': 'dresser'},
#  {'title': "metal 6' tower stand 4 glass shelves",
#   'price': '$50',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-metal-tower-stand-glass-shelves/7874123033.html',
#   'furniture_type': 'stand'},
#  {'title': 'microwave stand',
#   'price': '$30',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-microwave-stand/7892463545.html',
#   'furniture_type': 'stand'},
#  {'title': 'backers rack small corner black metal',
#   'price': '$30',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-backers-rack-small-corner-black/7894166635.html',
#   'furniture_type': 'rack'},
#  {'title': '4 black plastic shelf stand',
#   'price': '$20',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-black-plastic-shelf-stand/7896534555.html',
#   'furniture_type': 'shelf'},
#  {'title': 'bookcase/display shelves',
#   'price': '$20',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-bookcase-display-shelves/7872038267.html',
#   'furniture_type': 'missing'},
#  {'title': 'colorful full bookcase style headboard',
#   'price': '$20',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-colorful-full-bookcase-style/7874115397.html',
#   'furniture_type': 'bookcase'},
#  {'title': 'special display/bookcase stand 3 shelves',
#   'price': '$40',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-special-display-bookcase-stand/7880752281.html',
#   'furniture_type': 'stand'},
#  {'title': 'wood woven seat small rocking chair',
#   'price': '$10',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-wood-woven-seat-small-rocking-chair/7876421200.html',
#   'furniture_type': 'chair'},
#  {'title': 'rattan swivel, gliding rocker, recline chair',
#   'price': '$125',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-rattan-swivel-gliding-rocker/7906320708.html',
#   'furniture_type': 'chair'},
#  {'title': 'small drop leaf table (2) chairs',
#   'price': '$50',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-small-drop-leaf-table-chairs/7889737047.html',
#   'furniture_type': 'table'},
#  {'title': 'ladder back chair',
#   'price': '$15',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-ladder-back-chair/7900361874.html',
#   'furniture_type': 'chair'},
#  {'title': 'small heavy straight back school type chair/land nod mfg',
#   'price': '$15',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-small-heavy-straight-back-school/7910595972.html',
#   'furniture_type': 'missing'},
#  {'title': '2 metal frame design top/fabric seats chairs',
#   'price': '$15',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-metal-frame-design-top-fabric/7886573861.html',
#   'furniture_type': 'missing'},
#  {'title': '2 wood dining chairs',
#   'price': '$20',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-wood-dining-chairs/7910237983.html',
#   'furniture_type': 'missing'},
#  {'title': '2 black decorative leaf design back bar chairs',
#   'price': '$20',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-black-decorative-leaf-design-back/7911103073.html',
#   'furniture_type': 'bar'},
#  {'title': 'ethan allen desk',
#   'price': '$150',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-ethan-allen-desk/7910630653.html',
#   'furniture_type': 'desk'},
#  {'title': 'drop leaf table',
#   'price': '$50',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-drop-leaf-table/7895917913.html',
#   'furniture_type': 'table'},
#  {'title': 'wood server drop leaves',
#   'price': '$40',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-wood-server-drop-leaves/7900361774.html',
#   'furniture_type': 'missing'},
#  {'title': 'end/side/coffee table drop leaf',
#   'price': '$20',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-end-side-coffee-table-drop-leaf/7900988219.html',
#   'furniture_type': 'table'},
#  {'title': 'arm dining chairs (11)',
#   'price': '$5',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-arm-dining-chairs-11/7881034616.html',
#   'furniture_type': 'missing'},
#  {'title': 'vintage wood carving settee',
#   'price': '$150',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-vintage-wood-carving-settee/7886393130.html',
#   'furniture_type': 'settee'},
#  {'title': 'dresser (4) drawers',
#   'price': '$30',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-dresser-drawers/7881355136.html',
#   'furniture_type': 'dresser'},
#  {'title': 'beautiful design 42" round rug backing',
#   'price': '$20',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-beautiful-design-42-round-rug/7875431742.html',
#   'furniture_type': 'rug'},
#  {'title': 'rug 13\' 1/2" x 9\' 3" plus  padding',
#   'price': '$125',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-rug-9-plus-padding/7875763896.html',
#   'furniture_type': 'rug'},
#  {'title': 'large wall sconce (black)',
#   'price': '$250',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-large-wall-sconce-black/7903382148.html',
#   'furniture_type': 'missing'},
#  {'title': 'wood cabinet',
#   'price': '$50',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/earlysville-wood-cabinet/7912480094.html',
#   'furniture_type': 'cabinet'},
#  {'title': 'steelcase file cabinets',
#   'price': '$225',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-steelcase-file-cabinets/7912474967.html',
#   'furniture_type': 'missing'},
#  {'title': 'kurdish persian oriental rug runner',
#   'price': '$400',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/lexington-kurdish-persian-oriental-rug/7912468986.html',
#   'furniture_type': 'rug'},
#  {'title': 'mcm rare vintage bamboo folding plant ladder stand, mcm bookshelf',
#   'price': '$195',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-mcm-rare-vintage-bamboo/7872590674.html',
#   'furniture_type': 'missing'},
#  {'title': 'super sac, foot stool, and blanket',
#   'price': '$350',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-super-sac-foot-stool/7906533358.html',
#   'furniture_type': 'missing'},
#  {'title': 'small wood table with 2 chairs',
#   'price': '$30',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/montpelier-station-small-wood-table/7905320982.html',
#   'furniture_type': 'table'},
#  {'title': 'large oak rocking chair for sale',
#   'price': '$95',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/montpelier-station-large-oak-rocking/7905114541.html',
#   'furniture_type': 'chair'},
#  {'title': 'roveconcept hugo sectional, black, left-hand-facing, chrome',
#   'price': '$1,900',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-roveconcept-hugo/7912447793.html',
#   'furniture_type': 'missing'},
#  {'title': 'light pink vanity',
#   'price': '$125',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/montpelier-station-light-pink-vanity/7900254613.html',
#   'furniture_type': 'vanity'},
#  {'title': 'light pink vanity',
#   'price': '$90',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/montpelier-station-light-pink-vanity/7897804698.html',
#   'furniture_type': 'vanity'},
#  {'title': 'light pink vanity',
#   'price': '$125',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/montpelier-station-light-pink-vanity/7896333270.html',
#   'furniture_type': 'vanity'},
#  {'title': 'zinger! electric wheel chair',
#   'price': '$550',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/scottsville-zinger-electric-wheel-chair/7910952768.html',
#   'furniture_type': 'chair'},
#  {'title': 'kardiel josef kubus style mid-century modern lounge chair',
#   'price': '$400',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-kardiel-josef-kubus/7912398468.html',
#   'furniture_type': 'chair'},
#  {'title': 'kardiel josef kubus style mid-century modern sofa 3 seat',
#   'price': '$1,000',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-kardiel-josef-kubus/7912393652.html',
#   'furniture_type': 'sofa'},
#  {'title': 'vanity and night stand',
#   'price': '$120',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/somerset-vanity-and-night-stand/7912370778.html',
#   'furniture_type': 'vanity'},
#  {'title': 'pair of lovely upholstered vintage chairs',
#   'price': '$150',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/culpeper-pair-of-lovely-upholstered/7890928430.html',
#   'furniture_type': 'missing'},
#  {'title': 'samsung 42" tv with stand',
#   'price': '$90',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/ivy-samsung-42-tv-with-stand/7906385679.html',
#   'furniture_type': 'stand'},
#  {'title': 'afghan taimani oriental rug',
#   'price': '$100',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/lexington-afghan-taimani-oriental-rug/7912344533.html',
#   'furniture_type': 'rug'},
#  {'title': "kid's rocking chair",
#   'price': '$50',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/montpelier-station-kids-rocking-chair/7902072311.html',
#   'furniture_type': 'chair'},
#  {'title': 'kids bed, headboard only',
#   'price': '$200',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/montpelier-station-kids-bed-headboard/7902072427.html',
#   'furniture_type': 'headboard'},
#  {'title': '5 piece queen size bedroom set',
#   'price': '$1,000',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/montpelier-station-piece-queen-size/7903361006.html',
#   'furniture_type': 'missing'},
#  {'title': '5 piece full size bedroom set',
#   'price': '$2,000',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/montpelier-station-piece-full-size/7902072524.html',
#   'furniture_type': 'missing'},
#  {'title': 'adult rocking chair',
#   'price': '$250',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/montpelier-station-adult-rocking-chair/7902072357.html',
#   'furniture_type': 'chair'},
#  {'title': 'daybed frame',
#   'price': '$200',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/montpelier-station-daybed-frame/7902072476.html',
#   'furniture_type': 'missing'},
#  {'title': 'marble top dresser',
#   'price': '$250',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/montpelier-station-marble-top-dresser/7895469819.html',
#   'furniture_type': 'dresser'},
#  {'title': 'solid wood vintage bed frame',
#   'price': '$200',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-solid-wood-vintage-bed/7912276913.html',
#   'furniture_type': 'bed'},
#  {'title': 'ceiling lamps',
#   'price': '$10',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-ceiling-lamps/7906127676.html',
#   'furniture_type': 'missing'},
#  {'title': 'christmas special thomasville dining set 8 chairs table/china cabinet',
#   'price': '$500',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/montpelier-station-christmas-special/7876735137.html',
#   'furniture_type': 'cabinet'},
#  {'title': 'decorative metal wall piece',
#   'price': '$20',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-decorative-metal-wall-piece/7877432447.html',
#   'furniture_type': 'missing'},
#  {'title': 'lightweight 3"- 4" thick full mattress type',
#   'price': '$10',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-lightweight-thick-full-mattress/7872759460.html',
#   'furniture_type': 'missing'},
#  {'title': 'new mirrored wall art sound/lights package',
#   'price': '$75',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-new-mirrored-wall-art-sound-lights/7872760303.html',
#   'furniture_type': 'missing'},
#  {'title': 'antique washstand/mirror',
#   'price': '$250',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-antique-washstand-mirror/7872840543.html',
#   'furniture_type': 'missing'},
#  {'title': 'small table end/coffee decorative legs',
#   'price': '$20',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-small-table-end-coffee-decorative/7875719690.html',
#   'furniture_type': 'table'},
#  {'title': 'end table',
#   'price': '$20',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-end-table/7875721301.html',
#   'furniture_type': 'table'},
#  {'title': 'wood old rocking chair',
#   'price': '$20',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-wood-old-rocking-chair/7875721136.html',
#   'furniture_type': 'chair'},
#  {'title': 'small green fold table/artificial red poinsettia',
#   'price': '$10',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-small-green-fold-table-artificial/7876270942.html',
#   'furniture_type': 'missing'},
#  {'title': '(2) dining chairs white pull over covers',
#   'price': '$15',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-dining-chairs-white-pull-over/7876369959.html',
#   'furniture_type': 'missing'},
#  {'title': '(4) stanley artisan wood swivel bar stools',
#   'price': '$600',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-stanley-artisan-wood/7912209245.html',
#   'furniture_type': 'bar'},
#  {'title': 'vintage handmade solid wooden heavy bookshelf',
#   'price': '$80',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/greenwood-vintage-handmade-solid-wooden/7909628314.html',
#   'furniture_type': 'missing'},
#  {'title': 'large 3 tier cart',
#   'price': '$30',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-large-tier-cart/7879194883.html',
#   'furniture_type': 'cart'},
#  {'title': 'small square table',
#   'price': '$10',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-small-square-table/7880800418.html',
#   'furniture_type': 'table'},
#  {'title': 'small table wheels',
#   'price': '$10',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-small-table-wheels/7880830471.html',
#   'furniture_type': 'table'},
#  {'title': 'vintage headboard and footboard',
#   'price': '$30',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-vintage-headboard-and-footboard/7881627620.html',
#   'furniture_type': 'headboard'},
#  {'title': '5 drawer chest',
#   'price': '$30',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-drawer-chest/7881762858.html',
#   'furniture_type': 'chest'},
#  {'title': 'black lightweight  4 drawer chest',
#   'price': '$20',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-black-lightweight-drawer-chest/7881766433.html',
#   'furniture_type': 'chest'},
#  {'title': 'new daiwa qr750 ultralight spinning reel fishing 🎣',
#   'price': '$30',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-new-daiwa-qr750/7912184551.html',
#   'furniture_type': 'missing'},
#  {'title': '1 canvas you could hang',
#   'price': '$8',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-canvas-you-could-hang/7882456942.html',
#   'furniture_type': 'missing'},
#  {'title': 'new seaknight windrunner 4000 5.2.1 fishing 🎣 reel',
#   'price': '$30',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-new-seaknight/7912184306.html',
#   'furniture_type': 'missing'},
#  {'title': 'table wood trundle legs',
#   'price': '$30',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-table-wood-trundle-legs/7883848723.html',
#   'furniture_type': 'table'},
#  {'title': 'wood restaurant booth plus (2) tables',
#   'price': '$150',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-wood-restaurant-booth-plus-tables/7885992373.html',
#   'furniture_type': 'missing'},
#  {'title': 'colorful decorative trunk',
#   'price': '$30',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-colorful-decorative-trunk/7886553907.html',
#   'furniture_type': 'trunk'},
#  {'title': 'pair colorful flowers painted canvas',
#   'price': '$20',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-pair-colorful-flowers-painted/7886570151.html',
#   'furniture_type': 'missing'},
#  {'title': 'framed picture',
#   'price': '$20',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-framed-picture/7886570614.html',
#   'furniture_type': 'missing'},
#  {'title': 'ikea king size bedframe and nightstands',
#   'price': '$200',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-ikea-king-size-bedframe/7906156204.html',
#   'furniture_type': 'missing'},
#  {'title': 'antique chair',
#   'price': '$45',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-antique-chair/7893306184.html',
#   'furniture_type': 'chair'},
#  {'title': 'antique chair',
#   'price': '$45',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/barboursville-antique-chair/7874144458.html',
#   'furniture_type': 'chair'},
#  {'title': 'vintage metal full bed headboard/footboard',
#   'price': '$20',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-vintage-metal-full-bed-headboard/7889405235.html',
#   'furniture_type': 'bed'},
#  {'title': 'cool set electric lighted owls',
#   'price': '$30',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-cool-set-electric-lighted-owls/7889741651.html',
#   'furniture_type': 'missing'},
#  {'title': 'red storage box',
#   'price': '$5',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-red-storage-box/7892581884.html',
#   'furniture_type': 'missing'},
#  {'title': 'bunch framed pictures',
#   'price': '$5',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-bunch-framed-pictures/7897049515.html',
#   'furniture_type': 'missing'},
#  {'title': 'mantle clock',
#   'price': '$500',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/quinque-mantle-clock/7904075771.html',
#   'furniture_type': 'missing'},
#  {'title': 'qashqai persian oriental rug',
#   'price': '$200',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/lexington-qashqai-persian-oriental-rug/7912101579.html',
#   'furniture_type': 'rug'},
#  {'title': '4 tier wire storage cubicles',
#   'price': '$15',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-tier-wire-storage-cubicles/7891597352.html',
#   'furniture_type': 'missing'},
#  {'title': 'cd tower storage cabinet',
#   'price': '$10',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-cd-tower-storage-cabinet/7891599107.html',
#   'furniture_type': 'cabinet'},
#  {'title': "vintage child's desk",
#   'price': '$75',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/quinque-vintage-childs-desk/7908625577.html',
#   'furniture_type': 'desk'},
#  {'title': 'cherb gold color decorative frame',
#   'price': '$30',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-cherb-gold-color-decorative-frame/7901143248.html',
#   'furniture_type': 'missing'},
#  {'title': 'wooden cd/dvd holders',
#   'price': '$20',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/earlysville-wooden-cd-dvd-holders/7905296031.html',
#   'furniture_type': 'missing'},
#  {'title': 'zuri black leather executive desk chair',
#   'price': '$100',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/crozet-zuri-black-leather-executive/7908805902.html',
#   'furniture_type': 'desk'},
#  {'title': 'glass 3 shelf desk',
#   'price': '$39',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/crozet-glass-shelf-desk/7908806352.html',
#   'furniture_type': 'shelf'},
#  {'title': 'large cherry storage armoire',
#   'price': '$250',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/crozet-large-cherry-storage-armoire/7906113707.html',
#   'furniture_type': 'armoire'},
#  {'title': "vintage 1970's chevrolet tailgate bench",
#   'price': '$300',
#   'year': '1970',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/crozet-vintage-1970s-chevrolet-tailgate/7906010557.html',
#   'furniture_type': 'bench'},
#  {'title': "early mid 1900's egg and dart detailed book case",
#   'price': '$100',
#   'year': '1900',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/crozet-early-mid-1900s-egg-and-dart/7906112369.html',
#   'furniture_type': 'missing'},
#  {'title': 'bench/flower stand',
#   'price': '$20',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-bench-flower-stand/7880826471.html',
#   'furniture_type': 'stand'},
#  {'title': 'gold / tan soft chenille velvet feel chaise lounge sofa chair',
#   'price': '$50',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/montpelier-station-gold-tan-soft/7911986135.html',
#   'furniture_type': 'sofa'},
#  {'title': 'do you need help loading or unloading your truck?',
#   'price': '$65',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-do-you-need-help/7881120749.html',
#   'furniture_type': 'missing'},
#  {'title': 'ikea wooden storage cabinet (2)',
#   'price': '$60',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/greenwood-ikea-wooden-storage-cabinet/7884678392.html',
#   'furniture_type': 'cabinet'},
#  {'title': 'vintage heavy duty solid brass matching table lamps',
#   'price': '$150',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/greenwood-vintage-heavy-duty-solid/7910078342.html',
#   'furniture_type': 'table'},
#  {'title': 'metal side table with glass top',
#   'price': '$70',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/greenwood-metal-side-table-with-glass/7905377898.html',
#   'furniture_type': 'table'},
#  {'title': 'derk hansen woodland monarch framed deer picture',
#   'price': '$30',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-derk-hansen-woodland-monarch/7904100956.html',
#   'furniture_type': 'missing'},
#  {'title': 'beautiful frame colorful pheasants picture',
#   'price': '$20',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-beautiful-frame-colorful-pheasants/7904101319.html',
#   'furniture_type': 'missing'},
#  {'title': 'pair wood decorative bar stools',
#   'price': '$20',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-pair-wood-decorative-bar-stools/7906657949.html',
#   'furniture_type': 'bar'},
#  {'title': 'runner 9\'  3"',
#   'price': '$30',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-runner-3/7904676166.html',
#   'furniture_type': 'missing'},
#  {'title': 'free recliner = uhaul and it is yours',
#   'price': '$0',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-free-recliner-uhaul-and-it-is/7909502036.html',
#   'furniture_type': 'recliner'},
#  {'title': 'black wood desk',
#   'price': '$30',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-black-wood-desk/7905358753.html',
#   'furniture_type': 'desk'},
#  {'title': 'white wooden twin bed frame',
#   'price': '$35',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-white-wooden-twin-bed/7905358086.html',
#   'furniture_type': 'bed'},
#  {'title': 'metal foldable table',
#   'price': '$10',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/columbia-metal-foldable-table/7911924483.html',
#   'furniture_type': 'table'},
#  {'title': 'white twin wicker headboard/frame/slats/mattress',
#   'price': '$60',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-white-twin-wicker-headboard-frame/7879196016.html',
#   'furniture_type': 'missing'},
#  {'title': 'pair lamps good condition have feature  nite lite',
#   'price': '$40',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-pair-lamps-good-condition-have/7904021789.html',
#   'furniture_type': 'missing'},
#  {'title': 'wood drop leaf table',
#   'price': '$50',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-wood-drop-leaf-table/7880796457.html',
#   'furniture_type': 'table'},
#  {'title': 'sturdy drop leaf table 2 chairs',
#   'price': '$70',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-sturdy-drop-leaf-table-chairs/7881502826.html',
#   'furniture_type': 'table'},
#  {'title': 'drop leaf table',
#   'price': '$50',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/troy-drop-leaf-table/7887205552.html',
#   'furniture_type': 'table'},
#  {'title': 'reclining leather couch',
#   'price': '$165',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-reclining-leather-couch/7887539731.html',
#   'furniture_type': 'couch'},
#  {'title': 'twin or bunk beds -- vaughan of virginia',
#   'price': '$600',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-twin-or-bunk-beds/7877804026.html',
#   'furniture_type': 'missing'},
#  {'title': 'turkmen persian oriental rug',
#   'price': '$350',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/lexington-turkmen-persian-oriental-rug/7911878613.html',
#   'furniture_type': 'rug'},
#  {'title': 'hamadan persian oriental rug runner',
#   'price': '$450',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/lexington-hamadan-persian-oriental-rug/7911877148.html',
#   'furniture_type': 'rug'},
#  {'title': '2 vintage thomasville living room end tables',
#   'price': '$100',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/dillwyn-vintage-thomasville-living-room/7908922326.html',
#   'furniture_type': 'missing'},
#  {'title': 'solid wooden handmade queen/full size bed frame',
#   'price': '$350',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/greenwood-solid-wooden-handmade-queen/7902920710.html',
#   'furniture_type': 'bed'},
#  {'title': 'handmade solid wooden table',
#   'price': '$75',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/greenwood-handmade-solid-wooden-table/7907618845.html',
#   'furniture_type': 'table'},
#  {'title': 'chinese, "carved" 90-line, hand knotted wool runner 11\' x 28"',
#   'price': '$1,288',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-chinese-carved-90-line/7911822621.html',
#   'furniture_type': 'missing'},
#  {'title': 'chinese handcrafted carpet, large 10\' 3" x 8\' x 0.5"',
#   'price': '$1,480',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-chinese-handcrafted/7911791145.html',
#   'furniture_type': 'missing'},
#  {'title': 'area rugs 8x10 5x7 delivery available',
#   'price': '$1',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-area-rugs-8x10-5x7/7910281596.html',
#   'furniture_type': 'missing'},
#  {'title': 'thomas jackson stonewall michael gnateks',
#   'price': '$500',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/north-garden-thomas-jackson-stonewall/7909627189.html',
#   'furniture_type': 'missing'},
#  {'title': 'large and medium area rugs in excellent pet/smoke free condition',
#   'price': '$100',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/north-garden-large-and-medium-area-rugs/7908570681.html',
#   'furniture_type': 'missing'},
#  {'title': 'stanley furniture shelving hutch and desk',
#   'price': '$1',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/north-garden-stanley-furniture-shelving/7908051833.html',
#   'furniture_type': 'hutch'},
#  {'title': 'modern dining chairs - six',
#   'price': '$50',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-modern-dining-chairs-six/7908377635.html',
#   'furniture_type': 'missing'},
#  {'title': 'solid wood console table',
#   'price': '$325',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-solid-wood-console-table/7908377564.html',
#   'furniture_type': 'table'},
#  {'title': 'solid wood bar chairs',
#   'price': '$30',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-solid-wood-bar-chairs/7908377475.html',
#   'furniture_type': 'bar'},
#  {'title': 'solid wood end table',
#   'price': '$120',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-solid-wood-end-table/7911754919.html',
#   'furniture_type': 'table'},
#  {'title': 'couch gently used- teal sofa',
#   'price': '$125',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/montpelier-station-couch-gently-used/7911752751.html',
#   'furniture_type': 'couch'},
#  {'title': 'dining chairs 3 /4 white west elm vintage bentwood',
#   'price': '$150',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-dining-chairs-4-white/7911731911.html',
#   'furniture_type': 'missing'},
#  {'title': 'ikea toddler bed.',
#   'price': '$200',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/barboursville-ikea-toddler-bed/7893562520.html',
#   'furniture_type': 'missing'},
#  {'title': 'granite bistro table & chairs',
#   'price': '$235',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/barboursville-granite-bistro-table/7893562587.html',
#   'furniture_type': 'table'},
#  {'title': 'curio cabinets',
#   'price': '$250',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/barboursville-curio-cabinets/7893562640.html',
#   'furniture_type': 'missing'},
#  {'title': 'modern steel bar stools',
#   'price': '$325',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-modern-steel-bar-stools/7904586901.html',
#   'furniture_type': 'bar'},
#  {'title': 'mahal persian oriental rug',
#   'price': '$400',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/lexington-mahal-persian-oriental-rug/7911673432.html',
#   'furniture_type': 'rug'},
#  {'title': 'bakhtiari persian oriental rug',
#   'price': '$450',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/lexington-bakhtiari-persian-oriental-rug/7911665548.html',
#   'furniture_type': 'rug'},
#  {'title': 'dresser, 7-drawer',
#   'price': '$75',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-dresser-drawer/7911649713.html',
#   'furniture_type': 'missing'},
#  {'title': 'bamboo bar stool',
#   'price': '$15',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-bamboo-bar-stool/7876174284.html',
#   'furniture_type': 'bar'},
#  {'title': 'shelving system',
#   'price': '$20',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-shelving-system/7909301290.html',
#   'furniture_type': 'missing'},
#  {'title': 'posture chair',
#   'price': '$20',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-posture-chair/7909300675.html',
#   'furniture_type': 'chair'},
#  {'title': 'queen size mattress topper - less than 5 months old',
#   'price': '$55',
#   'year': nan,
# ...
#   'furniture_type': 'table'},
#  {'title': 'antique singer sewing base with choice of optional table top',
#   'price': '$75',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-antique-singer-sewing-base-with/7907796008.html',
#   'furniture_type': 'table'},
#  {'title': 'childs wicker bentwood rocking chair',
#   'price': '$32',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/keene-childs-wicker-bentwood-rocking/7907795884.html',
#   'furniture_type': 'chair'},
#  {'title': 'dual drop leaf dining room table',
#   'price': '$60',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-dual-drop-leaf-dining-room-table/7907795783.html',
#   'furniture_type': 'table'},
#  {'title': 'wicker archway with 5 shelves unit',
#   'price': '$99',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/keene-wicker-archway-with-shelves-unit/7906726747.html',
#   'furniture_type': 'missing'},
#  {'title': 'whiskey barrel base lamp',
#   'price': '$45',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/keene-whiskey-barrel-base-lamp/7906728082.html',
#   'furniture_type': 'lamp'},
#  {'title': 'exquisit brass like glass lighted show case',
#   'price': '$150',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/keene-exquisit-brass-like-glass-lighted/7906727507.html',
#   'furniture_type': 'missing'},
#  {'title': 'designer rolling metal table',
#   'price': '$35',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-designer-rolling-metal-table/7906723684.html',
#   'furniture_type': 'table'},
#  {'title': 'antique solid wood sewing table and built in chair',
#   'price': '$69',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-antique-solid-wood-sewing-table/7906726419.html',
#   'furniture_type': 'table'},
#  {'title': '2 pub table height solid wood chairs   each',
#   'price': '$25',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-pub-table-height-solid-wood/7906724296.html',
#   'furniture_type': 'table'},
#  {'title': 'solid wood, art room or project work table',
#   'price': '$25',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-solid-wood-art-room-or-project/7906723220.html',
#   'furniture_type': 'table'},
#  {'title': 'mid-century high back solid oak swivel bar stool #2',
#   'price': '$70',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-mid-century-high-back-solid-oak/7906722119.html',
#   'furniture_type': 'bar'},
#  {'title': 'mid-century high back solid oak swivel bar stool #1',
#   'price': '$69',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/keene-mid-century-high-back-solid-oak/7906721773.html',
#   'furniture_type': 'bar'},
#  {'title': 'quality solid wood rolling multi-use cart',
#   'price': '$42',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/keene-quality-solid-wood-rolling-multi/7906720040.html',
#   'furniture_type': 'cart'},
#  {'title': 'stemware, glasses and cordials from',
#   'price': '$0',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/keene-stemware-glasses-and-cordials-from/7906719756.html',
#   'furniture_type': 'missing'},
#  {'title': 'designer folding 60" wide room divider with bird house art work',
#   'price': '$175',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/keene-designer-folding-60-wide-room/7906719251.html',
#   'furniture_type': 'missing'},
#  {'title': 'chairs,  chairs and more chairs       and up',
#   'price': '$25',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-chairs-chairs-and-more-chairs/7906142181.html',
#   'furniture_type': 'missing'},
#  {'title': 'beautiful solid walnut glass door display case',
#   'price': '$120',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-beautiful-solid-walnut-glass/7906143098.html',
#   'furniture_type': 'missing'},
#  {'title': '"like new" rolling chrome clothes rack',
#   'price': '$25',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-like-new-rolling-chrome-clothes/7906141829.html',
#   'furniture_type': 'rack'},
#  {'title': 'farm house spice rack',
#   'price': '$45',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/keene-farm-house-spice-rack/7906141590.html',
#   'furniture_type': 'rack'},
#  {'title': 'perfect student dorm desk',
#   'price': '$39',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-perfect-student-dorm-desk/7906141196.html',
#   'furniture_type': 'desk'},
#  {'title': 'antique cobblers work bench circa 1850',
#   'price': '$195',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-antique-cobblers-work-bench/7906141478.html',
#   'furniture_type': 'bench'},
#  {'title': 'antique singer sewing machine base with tempered glass top',
#   'price': '$85',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/keene-antique-singer-sewing-machine/7906139887.html',
#   'furniture_type': 'missing'},
#  {'title': '2 brown and 2 black ladder back chairs with rush seating.   each',
#   'price': '$25',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-brown-and-black-ladder-back/7906140062.html',
#   'furniture_type': 'missing'},
#  {'title': 'colonial style 2 piece display hutch',
#   'price': '$145',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/keene-colonial-style-piece-display-hutch/7906140456.html',
#   'furniture_type': 'hutch'},
#  {'title': 'classic 8 bulb chandelier',
#   'price': '$50',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/keene-classic-bulb-chandelier/7906138574.html',
#   'furniture_type': 'missing'},
#  {'title': 'vintage style leaded glass look chandelier',
#   'price': '$50',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/keene-vintage-style-leaded-glass-look/7906138137.html',
#   'furniture_type': 'missing'},
#  {'title': 'antique gate leg dual drop leaf dining room table',
#   'price': '$135',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-antique-gate-leg-dual-drop-leaf/7906137731.html',
#   'furniture_type': 'table'},
#  {'title': 'antique victorian era dresser with ornate mirror',
#   'price': '$275',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-antique-victorian-era-dresser/7906137071.html',
#   'furniture_type': 'dresser'},
#  {'title': 'gone with the wind style lamp',
#   'price': '$40',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-gone-with-the-wind-style-lamp/7906136069.html',
#   'furniture_type': 'lamp'},
#  {'title': 'quality solid wood rolling multi-use cart',
#   'price': '$42',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/keene-quality-solid-wood-rolling-multi/7906135439.html',
#   'furniture_type': 'cart'},
#  {'title': '48" glass top, patio table with white metal leg base',
#   'price': '$89',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-48-glass-top-patio-table-with/7906135306.html',
#   'furniture_type': 'table'},
#  {'title': 'solian ware by soho pottery ltd.',
#   'price': '$44',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-solian-ware-by-soho-pottery-ltd/7901115915.html',
#   'furniture_type': 'missing'},
#  {'title': 'pitcher and bowl sets by ironstone u.s.a from',
#   'price': '$25',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-pitcher-and-bowl-sets-by/7901116065.html',
#   'furniture_type': 'missing'},
#  {'title': 'authentic barbara mock numbered (#1493)  framed print',
#   'price': '$20',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-authentic-barbara-mock-numbered/7901116432.html',
#   'furniture_type': 'missing'},
#  {'title': 'mirrors mirrors mirrors                                   from',
#   'price': '$25',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-mirrors-mirrors-mirrors-from/7901116559.html',
#   'furniture_type': 'missing'},
#  {'title': 'indoor/outdoor metal end tables each',
#   'price': '$30',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/keene-indoor-outdoor-metal-end-tables/7901116802.html',
#   'furniture_type': 'missing'},
#  {'title': 'vintage wicker stroller',
#   'price': '$99',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-vintage-wicker-stroller/7901117218.html',
#   'furniture_type': 'missing'},
#  {'title': 'black laquered bench',
#   'price': '$25',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-black-laquered-bench/7901116861.html',
#   'furniture_type': 'bench'},
#  {'title': 'early american style rocking chair',
#   'price': '$50',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/palmyra-early-american-style-rocking/7901116946.html',
#   'furniture_type': 'chair'},
#  {'title': 'oushak turkish oriental rug',
#   'price': '$800',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/lexington-oushak-turkish-oriental-rug/7910154300.html',
#   'furniture_type': 'rug'},
#  {'title': 'chenar persian oriental rug runner',
#   'price': '$350',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/lexington-chenar-persian-oriental-rug/7910152344.html',
#   'furniture_type': 'rug'},
#  {'title': 'make this brown overstuffed leather sofa yours today!',
#   'price': '$50',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-make-this-brown/7910064934.html',
#   'furniture_type': 'sofa'},
#  {'title': 'pair of shaker style or danish modern stickley chairs',
#   'price': '$400',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-pair-of-shaker-style-or/7908481655.html',
#   'furniture_type': 'missing'},
#  {'title': 'solid cherry bookshelf contemporary',
#   'price': '$400',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-solid-cherry-bookshelf/7908482546.html',
#   'furniture_type': 'missing'},
#  {'title': 'pair of shaker style or danish modern stickley chairs',
#   'price': '$400',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-pair-of-shaker-style-or/7908462463.html',
#   'furniture_type': 'missing'},
#  {'title': 'sarouk persian oriental rug',
#   'price': '$1,200',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/lexington-sarouk-persian-oriental-rug/7910020865.html',
#   'furniture_type': 'rug'},
#  {'title': 'cute side/ coffee table',
#   'price': '$40',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-cute-side-coffee-table/7909991444.html',
#   'furniture_type': 'table'},
#  {'title': 'pier 1 wicker chairs.',
#   'price': '$100',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-pier-wicker-chairs/7909990242.html',
#   'furniture_type': 'missing'},
#  {'title': 'full size white canopy bed',
#   'price': '$35',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-full-size-white-canopy/7907624059.html',
#   'furniture_type': 'bed'},
#  {'title': 'zabol persian oriental rug',
#   'price': '$350',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/lexington-zabol-persian-oriental-rug/7909928974.html',
#   'furniture_type': 'rug'},
#  {'title': 'reclaimed solid wood dresser',
#   'price': '$300',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-reclaimed-solid-wood/7909888263.html',
#   'furniture_type': 'dresser'},
#  {'title': 'two twin bed frames headboards and footboards (must take both)',
#   'price': '$80',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-two-twin-bed-frames/7897503139.html',
#   'furniture_type': 'bed'},
#  {'title': 'yalameh persian oriental rug',
#   'price': '$500',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/lexington-yalameh-persian-oriental-rug/7909633600.html',
#   'furniture_type': 'rug'},
#  {'title': 'antique enjilas persian oriental rug',
#   'price': '$350',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/lexington-antique-enjilas-persian/7909627648.html',
#   'furniture_type': 'rug'},
#  {'title': 'twin bed headboards- 25 each/45 pair',
#   'price': '$25',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-twin-bed-headboards-25/7890352713.html',
#   'furniture_type': 'bed'},
#  {'title': 'modern dog crate',
#   'price': '$80',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/waynesboro-modern-dog-crate/7909551474.html',
#   'furniture_type': 'missing'},
#  {'title': 'malayer persian oriental rug runner',
#   'price': '$450',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/lexington-malayer-persian-oriental-rug/7909511042.html',
#   'furniture_type': 'rug'},
#  {'title': 'bassett rolled arm sofa',
#   'price': '$150',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-bassett-rolled-arm-sofa/7909506639.html',
#   'furniture_type': 'sofa'},
#  {'title': 'four antique rugs',
#   'price': '$750',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-four-antique-rugs/7909492335.html',
#   'furniture_type': 'missing'},
#  {'title': 'mashad persian oriental rug',
#   'price': '$850',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/lexington-mashad-persian-oriental-rug/7909446254.html',
#   'furniture_type': 'rug'},
#  {'title': 'overstuffed plush recliner',
#   'price': '$65',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/esmont-overstuffed-plush-recliner/7883085474.html',
#   'furniture_type': 'recliner'},
#  {'title': 'wooden coffee table',
#   'price': '$50',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/esmont-wooden-coffee-table/7883084713.html',
#   'furniture_type': 'table'},
#  {'title': 'stools',
#   'price': '$5',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/esmont-stools/7883084989.html',
#   'furniture_type': 'missing'},
#  {'title': 'solid wood folding trestle table',
#   'price': '$100',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/esmont-solid-wood-folding-trestle-table/7883084543.html',
#   'furniture_type': 'table'},
#  {'title': '1960 desota',
#   'price': '$4,000',
#   'year': '1960',
#   'link': 'https://charlottesville.craigslist.org/fuo/d/waynesboro-1960-desota/7909394045.html',
#   'furniture_type': 'missing'},
#  {'title': 'nice grayish couch',
#   'price': '$100',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-nice-grayish-couch/7909387517.html',
#   'furniture_type': 'couch'},
#  {'title': 'bar wine cart on wheels',
#   'price': '$25',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/nellysford-bar-wine-cart-on-wheels/7909246888.html',
#   'furniture_type': 'bar'},
#  {'title': 'comfy red chair',
#   'price': '$40',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/charlottesville-comfy-red-chair/7909245254.html',
#   'furniture_type': 'chair'},
#  {'title': 'futon bed',
#   'price': '$200',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/barboursville-futon-bed/7898884618.html',
#   'furniture_type': 'futon'},
#  {'title': 'chairs. solid oak',
#   'price': '$60',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/waynesboro-chairs-solid-oak/7909182803.html',
#   'furniture_type': 'missing'},
#  {'title': 'sold oak chairs',
#   'price': '$60',
#   'year': nan,
#   'link': 'https://charlottesville.craigslist.org/fuo/d/waynesboro-sold-oak-chairs/7909182639.html',
#   'furniture_type': 'missing'}]

# %%
## Wrangle the data
df = pd.DataFrame.from_dict(data)
df['price'] = df['price'].str.replace('$','')
df['price'] = df['price'].str.replace(',','')
df['price'] = pd.to_numeric(df['price'],errors='coerce')
df['year'] = pd.to_numeric(df['year'],errors='coerce')
df['age'] = 2025-df['year']
print(df.shape)
df.to_csv('craigslist_cville_furniture.csv') # Save data in case of a disaster
df.head()
# Out:
# (357, 6)
#                                          title  price    year  \
# 0               bakhtiari persian oriental rug    350     NaN
# 1                    plant stand or table base     10     NaN
# 2         sept 2025 twin mattress/frame/spring    175  2025.0
# 3  custom storage unit ~ custom built cabinets   6500     NaN
# 4                          ball pythons rehome    150     NaN
#
#                                                 link furniture_type  age
# 0  https://charlottesville.craigslist.org/fuo/d/l...            rug  NaN
# 1  https://charlottesville.craigslist.org/fuo/d/l...          stand  NaN
# 2  https://charlottesville.craigslist.org/fuo/d/c...        missing  0.0
# 3  https://charlottesville.craigslist.org/fuo/d/c...        missing  NaN
# 4  https://charlottesville.craigslist.org/fuo/d/l...        missing  NaN

# %%
df.loc[:,['price','furniture_type']].groupby('furniture_type').describe()
# Out:
#                 price                                                        \
#                 count        mean         std    min     25%    50%     75%
# furniture_type
# armoire           1.0  250.000000         NaN  250.0  250.00  250.0  250.00
# bar              12.0  102.166667  179.330489    7.0   18.75   27.5   69.25
# bed               9.0  159.444444  197.380414   20.0   35.00   80.0  200.00
# bench             4.0  132.500000  139.672235   10.0   21.25  110.0  221.25
# bookcase          2.0   21.000000    1.414214   20.0   20.50   21.0   21.50
# cabinet           7.0  212.571429  224.052715   10.0   35.00   60.0  424.00
# cart              6.0   42.333333   29.917665   20.0   22.50   36.0   42.00
# chair            22.0  144.636364  185.599555   10.0   30.00   47.5  162.50
# chest             6.0  252.500000  296.643726   20.0   45.00  157.5  318.75
# couch             4.0  172.500000   89.116029  100.0  118.75  145.0  198.75
# desk             13.0   59.153846   52.386140   10.0   25.00   35.0   75.00
# dresser           8.0  218.750000  140.019131   30.0   87.50  262.5  312.50
# futon             1.0  200.000000         NaN  200.0  200.00  200.0  200.00
# headboard         3.0  226.666667  211.266025   30.0  115.00  200.0  325.00
# hutch             2.0   73.000000  101.823376    1.0   37.00   73.0  109.00
# lamp              6.0   21.666667   16.931233    5.0   10.00   15.0   35.00
# missing         132.0  261.060606  729.277953    0.0   20.00   60.0  180.00
# rack              5.0   31.000000    8.215838   25.0   25.00   30.0   30.00
# recliner          2.0   32.500000   45.961941    0.0   16.25   32.5   48.75
# rug              32.0  381.406250  243.082471   20.0  260.00  350.0  450.00
# settee            1.0  150.000000         NaN  150.0  150.00  150.0  150.00
# shelf             3.0   69.666667   70.216332   20.0   29.50   39.0   94.50
# sofa              8.0  315.500000  395.800094   50.0   68.75  124.5  375.00
# stand             8.0   70.625000   95.858434   10.0   23.75   35.0   60.00
# table            54.0  153.074074  390.735052   10.0   40.00   64.5  123.75
# trunk             1.0   30.000000         NaN   30.0   30.00   30.0   30.00
# vanity            4.0  115.000000   16.832508   90.0  112.50  122.5  125.00
# wardrobe          1.0  350.000000         NaN  350.0  350.00  350.0  350.00
#
#
#                    max
# furniture_type
# armoire          250.0
# bar              600.0
# bed              600.0
# bench            300.0
# bookcase          22.0
# cabinet          500.0
# cart             100.0
# chair            550.0
# chest            800.0
# couch            300.0
# desk             175.0
# dresser          395.0
# futon            200.0
# headboard        450.0
# hutch            145.0
# lamp              45.0
# missing         6500.0
# rack              45.0
# recliner          65.0
# rug             1200.0
# settee           150.0
# shelf            150.0
# sofa            1000.0
# stand            300.0
# table           2800.0
# trunk             30.0
# vanity           125.0
# wardrobe         350.0

# %%
df['price'].hist(bins = 100)
# Out:
# <Axes: >

# %%
sns.kdeplot(df['price'])
plt.show()

# %%
sns.kdeplot(df,x='price',hue='furniture_type', common_norm=False)
plt.show()
# Out:
# /tmp/ipython-input-2828214192.py:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(df,x='price',hue='furniture_type', common_norm=False)

# %%
sns.boxplot(df,x='price',y='furniture_type',showfliers=False )
# Out:
# <Axes: xlabel='price', ylabel='furniture_type'>
